# %%
import os

import numpy as np
import open_clip
import torch
from PIL import Image
from torch.ao.nn.quantized.functional import threshold
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from src import config

# %%
print("Using device:", config.DEVICE)
# Out:
# Using device: mps

# %%
def load_image_embeddings_from_dir(dir_path):
    embeddings = []
    for file in os.listdir(dir_path):
        if file.endswith('.npy'):
            emb = np.load(os.path.join(dir_path, file))
            embeddings.append(torch.tensor(emb))
    return torch.stack(embeddings)

def load_metadata_embeddings_from_dir(dir_path):
    embeddings = []
    for file in os.listdir(dir_path):
        if file.endswith('_caption.npy'):
            emb = np.load(os.path.join(dir_path, file))
            embeddings.append(torch.tensor(emb))
    return torch.stack(embeddings)

# %%
# Load user likes and dislikes (images)
liked_image_embeddings = load_image_embeddings_from_dir(config.EMBEDDINGS_SEGMENTED_POS_OUTFITS_DIR)
disliked_image_embeddings = load_image_embeddings_from_dir(config.EMBEDDINGS_SEGMENTED_NEG_OUTFITS_DIR)

# %%
print(liked_image_embeddings.shape)
# Out:
# torch.Size([816, 1, 512])

# %%
print(disliked_image_embeddings.shape)
# Out:
# torch.Size([4531, 1, 512])

# %%
print(liked_image_embeddings[0].shape)
# Out:
# torch.Size([1, 512])

# %%
print(liked_image_embeddings[0])
# Out:
# tensor([[ 6.5039e-01, -7.1167e-02,  3.8184e-01,  1.6982e+00,  4.9048e-01,
#           3.8159e-01, -4.5357e-03, -1.7847e-01,  8.6670e-01,  1.4526e-01,
#          -1.3843e-01,  2.0996e-01,  1.6504e-01, -2.8442e-01,  6.2256e-01,
#          -1.6968e-02,  2.0435e-01,  7.1045e-02, -2.6538e-01,  2.0776e-01,
#          -5.0244e-01, -4.4653e-01, -1.0187e-01, -1.8809e+00,  5.3857e-01,
#          -2.6880e-01,  1.8110e-03,  6.9531e-01,  6.5625e-01,  5.6299e-01,
#           2.1118e-01,  1.0841e-02, -8.1299e-01, -3.9844e-01, -1.9727e-01,
#           3.6206e-01,  1.3403e-01,  5.6689e-01,  4.2017e-01, -2.5562e-01,
#          -5.3711e-01,  2.3254e-01, -5.6494e-01, -5.3271e-01,  4.1333e-01,
#           2.9053e-01, -3.6035e-01,  3.5425e-01, -7.6465e-01, -1.5225e+00,
#          -1.0469e+00, -4.7144e-01, -2.6904e-01, -6.0840e-01,  1.8811e-01,
#          -5.4443e-01, -4.3506e-01, -3.4009e-01,  1.5918e-01, -5.6689e-01,
#           4.1809e-02, -2.9572e-02,  7.7588e-01, -1.1359e-01, -4.2542e-02,
#          -1.5491e-01,  3.1714e-01, -5.6934e-01,  7.3303e-02,  4.3115e-01,
#           1.5735e-01, -2.5439e-01, -9.1406e-01,  2.2070e-01, -7.0068e-01,
#          -4.2969e-02, -4.8511e-01,  1.0732e+00, -2.4329e-01, -7.2559e-01,
#           2.5073e-01,  1.4697e-01, -6.1523e-02, -5.1123e-01, -2.9907e-01,
#          -1.1713e-01,  1.7273e-01,  6.0938e-01,  4.2285e-01,  5.3418e-01,
#           8.7988e-01, -2.3877e-01, -2.9614e-01,  1.0309e-01,  1.7334e-01,
#          -4.5715e-02,  1.6040e-01, -6.9189e-01, -9.6069e-02, -1.2871e+00,
#          -2.7368e-01,  2.7710e-02,  9.3323e-02, -3.8208e-02, -5.1562e-01,
#          -1.4783e-01,  4.1504e-01,  4.9530e-02, -8.5791e-01,  1.0425e-01,
#           5.8301e-01, -6.4575e-02,  9.3652e-01,  8.3557e-02,  1.2695e-01,
#           1.4844e-01, -4.8877e-01,  4.6387e-01,  2.6660e-01,  1.1182e-01,
#           6.2695e-01, -5.0830e-01,  4.2505e-01,  1.3416e-01, -1.0820e+00,
#           8.0322e-01,  3.9893e-01, -1.8982e-01,  2.1594e-01,  1.5587e-02,
#           4.0942e-01,  3.0981e-01, -2.4582e-02, -3.6426e-01,  5.5664e-01,
#           6.1737e-02, -2.9004e-01, -7.2327e-02, -2.9761e-01,  2.5439e-01,
#           4.5654e-01, -5.4626e-02,  1.0846e-01, -8.6328e-01, -8.5645e-01,
#          -2.0618e-01, -3.4790e-03, -1.9592e-01, -2.9150e-01, -6.9092e-01,
#           3.4570e-01,  5.3009e-02, -4.6661e-02, -1.9434e-01,  7.4158e-02,
#           3.7500e-01,  1.5225e+00, -1.0244e+00, -4.0527e-01, -4.2456e-01,
#           1.6582e+00,  8.5876e-02,  1.0547e-01, -6.3232e-01,  9.7070e-01,
#          -3.6377e-01, -5.0049e-01, -1.6006e-02, -2.3071e-01,  4.8920e-02,
#          -1.1707e-01,  1.5343e-02, -9.4238e-01, -3.3740e-01,  2.3865e-02,
#           8.3789e-01, -3.0835e-01,  1.1084e-01,  6.7688e-02, -2.6318e-01,
#          -4.1382e-01, -5.5127e-01,  4.4458e-01, -6.4160e-01, -5.5957e-01,
#          -6.8750e-01, -1.1986e-02, -1.1102e-01,  2.1228e-01,  1.0078e+00,
#          -6.1157e-02,  2.3096e-01, -3.3301e-01,  3.3594e-01, -3.3423e-01,
#           1.6248e-01,  1.5759e-01, -3.0029e-01,  1.2659e-01,  4.4800e-01,
#          -1.7212e-01, -1.7773e-01,  2.4463e-01, -6.8262e-01, -2.3438e-01,
#           6.7969e-01,  4.9805e-01,  3.4863e-01,  2.2461e+00, -1.5979e-01,
#           8.7402e-02, -2.3169e-01,  9.0723e-01,  6.2158e-01,  4.0588e-02,
#          -3.5938e-01,  9.7534e-02, -6.7627e-02,  8.5815e-02, -8.3313e-02,
#          -5.9033e-01,  6.5479e-01,  1.7383e-01, -6.1475e-01, -8.2825e-02,
#           1.8103e-01,  4.6509e-01,  4.7583e-01, -3.2129e-01, -3.7207e-01,
#          -6.0703e+00,  3.3203e-01,  2.2278e-01, -1.1992e+00, -4.4971e-01,
#           9.1162e-01, -5.0293e-01,  5.7587e-02, -1.3535e+00, -2.2681e-01,
#          -3.9502e-01,  4.3628e-01, -4.8256e-03, -1.9177e-01, -4.5850e-01,
#           1.6052e-01, -1.1224e-01,  2.1439e-02,  1.6455e-01,  1.1353e-02,
#           1.6687e-01, -5.4590e-01,  1.2183e-01,  2.7417e-01, -2.7368e-01,
#          -7.0801e-01,  1.2848e-02,  5.3125e-01, -1.7217e+00, -2.5986e-02,
#          -4.8309e-02, -3.2300e-01, -7.2852e-01, -3.3740e-01,  1.6577e-01,
#          -5.3589e-02,  4.9414e-01,  8.9661e-02, -2.8275e-02,  3.0713e-01,
#           4.4482e-01,  2.7075e-01,  2.8247e-01, -3.5620e-01, -2.2717e-01,
#           1.4233e-01, -3.0811e-01,  5.2832e-01,  1.2891e-01,  7.6843e-02,
#          -1.4294e-01, -1.0381e+00,  2.5787e-02,  2.1172e+00,  2.9125e-03,
#          -1.4008e-02, -8.6792e-02,  3.6224e-02,  2.6562e-01,  4.3042e-01,
#          -5.0098e-01, -1.7493e-01, -5.4291e-02,  4.0845e-01, -6.1523e-02,
#           2.5146e-01,  2.7734e-01, -2.6973e+00, -3.6841e-01, -6.2347e-02,
#           1.0176e+00,  6.4307e-01,  3.2178e-01, -3.0933e-01, -5.7422e-01,
#           6.0547e-01,  1.6467e-01,  3.0762e-02,  1.8701e-01,  1.7322e-01,
#          -3.4766e-01, -6.2842e-01, -7.3633e-01,  4.2676e-01, -4.4214e-01,
#          -7.1387e-01,  3.4912e-01, -1.6172e+00,  2.9199e-01,  7.4609e-01,
#          -5.3027e-01, -3.6401e-01, -8.4412e-02,  1.4587e-01, -5.1318e-01,
#           4.9896e-02,  2.7979e-01,  1.8213e-01, -4.6356e-02,  5.3320e-01,
#          -3.5583e-02,  3.4619e-01, -4.4128e-02, -6.0254e-01, -6.5039e-01,
#           3.7329e-01, -2.1558e-01,  2.9907e-01,  9.0332e-02,  8.2275e-02,
#          -5.1318e-01,  4.0161e-01,  2.9175e-01,  6.2927e-02, -1.5411e-03,
#           1.1359e-01, -3.1055e-01, -4.2041e-01,  7.3730e-01,  5.5420e-01,
#          -4.3994e-01, -7.4170e-01,  1.9141e-01,  3.8989e-01, -3.3374e-01,
#           1.7419e-01, -5.6445e-01, -1.9946e-01, -3.0029e-01,  7.1387e-01,
#           3.9575e-01, -1.7688e-01, -4.3628e-01, -8.3496e-01,  7.4219e-01,
#          -6.7578e-01,  3.9722e-01, -2.1805e-02,  6.6406e-02,  4.5850e-01,
#           1.0541e-01,  5.4736e-01, -6.9385e-01, -2.5195e-01, -3.7781e-02,
#           4.0479e-01, -1.3135e-01,  4.7241e-01, -5.4053e-01,  1.5833e-01,
#          -4.1748e-01, -6.9238e-01, -3.5400e-01, -4.0649e-01,  2.1570e-01,
#          -1.8323e-01,  5.5713e-01, -7.1875e-01, -3.1763e-01, -4.4238e-01,
#          -8.0811e-01, -1.5845e-01,  4.8218e-01, -1.2634e-01, -7.5879e-01,
#          -4.5349e-02, -4.2847e-01,  9.8206e-02, -6.0303e-02, -3.5620e-01,
#          -2.5366e-01,  2.4048e-01,  9.1309e-01, -5.5176e-01, -5.4102e-01,
#          -2.6587e-01,  3.7720e-01, -6.0059e-01,  3.7628e-02,  7.7002e-01,
#          -3.1177e-01, -5.2643e-02, -1.9238e-01,  9.5520e-02, -1.0109e-02,
#          -1.1261e-01, -5.6152e-02, -5.0830e-01,  2.3254e-01, -5.9326e-02,
#           2.3999e-01, -7.2021e-02, -9.6045e-01,  1.0895e-01,  6.0742e-01,
#           1.2189e-01,  4.6753e-01,  1.0602e-01,  2.2742e-01, -4.8633e-01,
#          -1.7651e-01, -1.9617e-01,  4.7559e-01, -3.6108e-01, -8.5449e-02,
#           1.3354e-01,  3.4149e-02, -1.4465e-01,  2.1082e-01, -1.7041e-01,
#          -1.7670e-02, -5.4980e-01, -1.1917e-02, -8.5840e-01, -1.2168e+00,
#           7.9541e-01, -7.6599e-02,  4.1113e-01,  7.4512e-01, -3.4473e-01,
#          -3.0298e-01,  7.5732e-01,  2.3669e-01, -2.6660e-01, -7.7197e-01,
#          -9.4666e-02, -7.9541e-01, -5.1025e-01,  4.0942e-01,  4.3945e-01,
#           3.4985e-01, -2.1411e-01, -4.8145e-01, -3.9160e-01,  6.5002e-02,
#          -1.4856e-01, -1.4294e-01,  5.0391e-01,  4.3457e-02, -7.9004e-01,
#           5.5811e-01,  2.0581e-01, -2.0959e-01, -8.5297e-03, -6.3574e-01,
#           1.3940e-01,  3.6816e-01,  7.3364e-02, -5.6299e-01, -1.0266e-01,
#          -2.8809e-01,  1.6162e-01, -5.5859e-01, -1.2915e-01, -8.5986e-01,
#          -2.3499e-01, -5.1318e-01, -1.7236e-01,  5.0391e-01,  3.2251e-01,
#           7.7393e-01,  3.2422e-01,  4.7803e-01, -7.0251e-02,  2.9443e-01,
#          -3.1769e-02, -5.0391e-01, -1.1005e-01,  7.5049e-01, -9.7705e-01,
#          -1.8359e-01, -2.1606e-01,  1.0508e+00, -6.3770e-01, -3.6792e-01,
#           1.1078e-01,  5.8936e-01,  4.1431e-01, -3.2251e-01, -5.9766e-01,
#          -7.9443e-01,  1.0199e-01]])

# %%
print("min", torch.min(liked_image_embeddings[0]))
print("max", torch.max(liked_image_embeddings[0]))
# Out:
# min tensor(-6.0703)
# max tensor(2.2461)

# %%
similarity = F.cosine_similarity(F.normalize(liked_image_embeddings[0], dim=-1), F.normalize(disliked_image_embeddings[80], dim=-1), dim=-1)
print("Cosine similarity score:", similarity.item())

similarity = F.cosine_similarity(F.normalize(liked_image_embeddings[0], dim=-1), F.normalize(liked_image_embeddings[8], dim=-1), dim=-1)
print("Cosine similarity score:", similarity.item())

# no difference between normalized and not normalized
# Out:
# Cosine similarity score: 0.48054736852645874
# Cosine similarity score: 0.46512293815612793

# %%
# dot product
# new_liked_image_embeddings = liked_image_embeddings/np.linalg.norm(liked_image_embeddings, ord=2, axis=-1, keepdims=True)
# new_disliked_image_embeddings = disliked_image_embeddings/np.linalg.norm(disliked_image_embeddings, ord=2, axis=-1, keepdims=True)

# %%
# Create personal style anchor
style_anchor = torch.mean(liked_image_embeddings, dim=0, keepdim=True)

# Create negative style anchor
negative_anchor = torch.mean(disliked_image_embeddings, dim=0, keepdim=True)

# %%
print("style_anchor shape:", style_anchor.shape)
print("Style Anchor Embedding:", style_anchor)
# Out:
# style_anchor shape: torch.Size([1, 1, 512])
# Style Anchor Embedding: tensor([[[ 3.1263e-01,  2.1046e-02,  9.8415e-01,  7.0405e-01,  1.2590e-01,
#            9.4716e-03,  7.0533e-03, -2.0593e-01,  3.0972e-01,  3.3591e-01,
#            2.4057e-01, -3.7011e-02,  9.2569e-02, -1.1175e-01,  6.4867e-02,
#           -5.5690e-01,  2.2929e-02, -1.1523e-01,  6.4453e-03,  1.8714e-01,
#           -4.2866e-01, -7.6405e-02,  2.2310e-01, -1.7353e+00,  2.1232e-02,
#            2.9180e-01, -7.4424e-03,  1.4595e-01,  1.1066e-01, -1.1848e-01,
#           -5.2210e-01,  2.8804e-01, -2.7563e-01, -5.9863e-02, -3.4566e-01,
#            3.0929e-01,  3.5462e-01, -1.5565e-01,  1.0833e-01, -2.7737e-01,
#           -1.5877e-01,  3.7248e-02,  2.1774e-01, -4.9635e-02,  4.7212e-01,
#           -1.1349e-01, -3.8900e-01,  1.0901e-01, -2.3257e-01, -2.7758e-01,
#           -4.0346e-01, -2.2742e-01,  1.6481e-01,  2.2738e-01, -1.6640e-01,
#           -2.3008e-01,  1.7722e-02, -5.0922e-02, -2.8895e-02, -2.3505e-01,
#           -4.0952e-02, -4.0721e-01,  3.5710e-01, -2.4504e-01, -4.0749e-02,
#            2.8960e-02, -1.5629e-01, -3.7295e-02, -1.3546e-01,  3.7765e-02,
#            2.9592e-01,  2.8968e-01,  2.7943e-02, -1.6642e-02,  1.3540e-02,
#           -6.7238e-02, -1.7234e-01,  5.3167e-01, -7.5266e-03, -5.9410e-01,
#            2.3981e-01,  1.3870e-01, -1.5267e-01, -5.5587e-01, -5.8438e-01,
#            2.8518e-01, -1.6284e-02,  3.3024e-01,  2.1354e-01,  3.1819e-01,
#            1.1196e-01, -2.4304e-01, -2.0078e-01,  1.3838e-01, -2.1929e-01,
#            1.1541e-01, -1.9057e-02,  1.4881e-01,  1.8825e-01,  1.7722e-01,
#           -2.9596e-01, -7.9416e-02, -4.8993e-02,  2.0912e-01, -7.1332e-03,
#           -3.7974e-01,  2.2274e-01, -2.2394e-01, -2.2357e-02,  5.3623e-02,
#            6.1622e-02,  9.0013e-02,  8.7225e-01,  8.8889e-02, -6.8437e-02,
#           -1.1328e-01, -2.5297e-01,  1.5916e-01,  3.8052e-01, -1.4276e-01,
#           -1.6502e-02,  5.7445e-02,  1.1335e-01, -3.7733e-02, -2.3988e-01,
#            3.7709e-01, -1.0569e-01,  6.0716e-02,  6.6600e-01,  7.9981e-02,
#            2.8320e-02,  5.1215e-02, -1.3627e-01, -1.5999e-01, -2.0977e-02,
#           -1.0299e-01,  1.1330e-01, -1.1358e-01, -1.6517e-01,  3.6237e-01,
#            4.0603e-01, -6.6206e-02,  6.7884e-01,  3.5969e-01,  1.2876e-01,
#            2.3518e-01,  9.2271e-02, -3.6622e-02,  4.6290e-02, -2.8223e-01,
#            5.3475e-01, -3.8725e-03,  9.1413e-02, -1.2130e-01,  6.4266e-01,
#            2.3032e-01,  4.3492e-02, -4.9229e-01,  6.6006e-02, -4.3056e-02,
#            1.7182e+00,  1.0218e-01,  3.0993e-01, -1.5652e-01,  4.4469e-01,
#           -2.1909e-01, -8.6418e-02,  1.9121e-01, -2.8986e-01, -1.9447e-02,
#            1.2791e-01,  1.4330e-01,  1.0311e-01, -3.7433e-02, -6.7353e-02,
#            3.8082e-01, -9.3758e-02,  9.9771e-03,  2.2161e-01, -1.3765e-01,
#           -3.8477e-01, -1.0867e+00,  2.2665e-02,  2.2301e-01, -2.5671e-03,
#            1.4935e-01,  2.5085e-01, -1.4678e-01,  8.3742e-02,  4.9326e-01,
#            2.0602e-01,  3.6447e-01, -2.5349e-01,  2.2125e-01,  1.9526e-01,
#           -9.1229e-02, -3.5004e-01,  1.1711e-01,  1.5815e-01,  3.5657e-01,
#           -2.6864e-01, -4.9274e-03,  1.0039e-01, -3.2721e-01, -2.9617e-01,
#            2.5698e-02,  2.5234e-01, -1.0610e-01,  5.0139e-01, -1.2899e-01,
#            1.6029e-01, -1.7802e-01,  9.2166e-02, -4.7495e-03, -1.4807e-01,
#           -7.5789e-02,  1.5514e-01, -7.5682e-02, -1.0365e-01,  5.8993e-02,
#           -3.9539e-01, -5.6517e-01,  1.5131e-02,  1.1555e-02, -2.2995e-01,
#           -8.5450e-04,  5.7853e-02,  2.5068e-01, -8.3548e-02, -1.8922e-01,
#           -6.1928e+00, -2.7367e-01, -2.4076e-01, -9.9334e-01, -1.1868e-02,
#           -2.6178e-01, -4.2834e-01, -1.8277e-01, -8.6659e-01, -3.8600e-02,
#           -4.0927e-01,  2.6332e-02,  1.2941e-01,  4.7985e-02, -1.4928e-01,
#            8.5237e-02, -3.6041e-02,  1.1622e-01,  2.3859e-01,  6.1827e-01,
#            6.8724e-02, -8.0040e-02, -2.0407e-01,  1.3693e-01,  5.6561e-02,
#            2.5681e-01, -1.3225e-01,  1.1283e-01, -7.0760e-01, -2.5517e-01,
#            8.7872e-02, -1.8872e-01, -4.1167e-01, -1.2457e-01, -5.4374e-02,
#           -2.6310e-02,  1.7315e-01,  1.7767e-01, -1.7930e-01, -2.3519e-01,
#            3.6035e-01,  3.3816e-02,  2.2838e-01, -8.0991e-02, -4.1502e-01,
#            1.4267e-01,  2.3768e-01,  1.9052e-01,  1.6036e-01,  3.9665e-01,
#            7.6019e-02, -4.2438e-01,  3.6748e-01,  1.7304e+00, -6.3364e-03,
#            8.0153e-02,  3.8140e-01, -5.9776e-01, -3.2777e-02, -2.8234e-01,
#            3.5915e-01,  7.5612e-02, -1.8004e-01,  9.1545e-02,  3.2385e-02,
#            3.8056e-02, -1.1425e-02, -2.3194e+00, -9.1231e-02,  6.5862e-01,
#           -5.9163e-02,  4.8015e-01,  2.4326e-01,  1.6802e-02, -1.5438e-01,
#            7.2167e-02,  1.0725e-01, -4.2976e-01,  1.1849e-01, -7.8447e-02,
#            1.8186e-01, -1.0235e-01, -4.7717e-02,  3.2195e-01, -1.8409e-01,
#           -3.9114e-01,  1.6486e-01, -4.1097e-01, -1.1048e-01,  4.0069e-02,
#           -2.8034e-01, -5.3325e-02,  9.2265e-02,  1.2056e-01, -5.3939e-02,
#            2.2697e-01,  3.9665e-01, -4.6693e-02, -1.4635e-01,  3.9044e-01,
#           -1.0794e-01, -1.7450e-01, -3.0936e-01, -1.5165e-01,  6.7978e-02,
#            1.0680e-01,  3.6044e-01,  2.1163e-01,  3.7553e-01,  2.6554e-01,
#           -2.4561e-01,  4.7148e-01, -2.3348e-01,  2.9870e-01,  3.5120e-02,
#            9.8371e-02, -2.0005e-01, -7.8314e-02,  3.8989e-01, -1.6267e-01,
#           -7.9215e-02, -8.9028e-02,  2.1879e-01, -1.7158e-01, -4.0381e-01,
#           -1.1650e-01, -1.2877e-02, -1.1636e-01, -1.7243e-01,  7.1050e-02,
#           -1.3563e-01,  1.3835e-01, -1.9561e-01, -2.1537e-01,  1.4364e-01,
#           -1.5126e-01, -9.7716e-02, -1.1910e-02, -3.0939e-01,  1.6362e-01,
#            4.4583e-01,  5.1508e-02, -4.3654e-01, -3.3458e-01, -3.2054e-01,
#            7.9640e-02, -2.4638e-02, -3.3578e-01, -1.3600e-01,  1.7788e-01,
#            1.3618e-01,  4.8141e-02, -1.1022e-01, -1.2499e-01,  3.3318e-01,
#            2.5382e-03,  6.5847e-02, -4.2886e-01, -2.3959e-01,  1.7103e-01,
#            3.4109e-01, -1.2460e-01,  4.7952e-01,  1.2280e-01,  5.6961e-01,
#           -3.0836e-01, -4.7437e-01,  4.7664e-02,  1.7154e-01,  2.5113e-01,
#            1.9395e-01,  6.9291e-02, -3.7938e-02, -3.2636e-01,  1.2002e-01,
#           -2.2388e-01, -8.6628e-02,  7.2159e-02, -2.4731e-01,  3.4733e-01,
#           -3.4215e-01, -3.0539e-02,  3.4578e-02,  2.7201e-02,  2.5352e-01,
#            6.5240e-02, -1.0104e-01, -4.8406e-02, -2.7297e-01, -1.0529e-01,
#            2.1447e-02,  5.7768e-03, -8.9564e-02, -7.6653e-02,  1.4622e-01,
#           -1.6972e-01,  2.3817e-01, -1.4991e-01, -1.5178e-01, -3.0072e-01,
#            2.4936e-02, -2.6920e-01, -1.5517e-01, -1.8188e-01, -2.3250e-02,
#           -3.3233e-01, -9.5915e-02,  1.8072e-01,  3.4764e-01, -3.0261e-01,
#           -2.0474e-03, -1.4509e-01, -2.4503e-01, -2.4411e-01, -4.1746e-01,
#            8.5355e-01, -1.7956e-01, -1.5356e-01,  1.2350e-01,  5.5347e-01,
#           -3.5054e-01,  3.2584e-02, -6.1383e-02, -3.6215e-01, -2.1147e-01,
#           -2.7800e-01, -8.0740e-01,  7.6826e-02,  1.0467e-01,  2.5053e-01,
#            5.4336e-01, -5.8201e-01,  1.7737e-02,  1.1108e-02,  6.6276e-02,
#            2.6255e-01, -3.2956e-01,  1.0101e-01, -6.5908e-02,  2.3301e-01,
#            1.3528e-01,  1.5954e-01, -1.3960e-01,  3.0734e-01, -3.1585e-01,
#            1.7451e-01, -5.8630e-02,  2.9407e-01, -6.4789e-02,  7.6492e-02,
#            7.9017e-02,  1.8822e-01,  1.2311e-01, -1.0279e-02, -2.2509e-01,
#           -1.3517e-01, -3.4066e-01, -4.2621e-01, -2.7576e-01,  1.1961e-01,
#            2.4604e-01, -7.8101e-02, -1.9491e-01,  9.2337e-02,  1.3747e-01,
#           -4.0895e-02, -4.1854e-02, -9.2979e-02,  6.1835e-01, -8.1208e-01,
#           -1.7150e-01,  1.0968e-02,  5.3689e-01, -3.6685e-01, -1.5694e-01,
#           -2.1093e-01,  2.7053e-01,  5.0017e-02,  5.8728e-02, -2.0759e-01,
#           -2.8412e-01,  7.4637e-02]]])

# %%
print("negative_anchor shape:", negative_anchor.shape)
print("Negative Anchor Embedding:", negative_anchor)
# Out:
# negative_anchor shape: torch.Size([1, 1, 512])
# Negative Anchor Embedding: tensor([[[ 4.6389e-01, -3.7068e-03,  1.1371e+00,  6.5363e-01,  2.7299e-01,
#            1.2313e-01, -6.6666e-02, -2.1502e-02,  1.6423e-01,  2.0017e-01,
#            1.4286e-01,  3.7322e-02,  1.6859e-01, -1.2475e-01,  1.2703e-01,
#           -1.1470e-01, -8.4155e-02, -1.8580e-01, -8.1583e-02,  1.8141e-01,
#           -5.0163e-01, -2.2163e-01, -7.4979e-02, -1.5879e+00,  1.6355e-01,
#            2.0963e-01,  1.1418e-01,  5.9576e-03,  2.6664e-01,  1.1309e-01,
#           -4.4484e-01,  1.5087e-01, -3.3179e-01,  9.0865e-02, -2.3829e-01,
#            3.6133e-01,  3.4359e-01, -2.0637e-02,  1.0944e-01, -8.8985e-02,
#           -1.8615e-01,  1.4062e-02, -6.8003e-02, -9.8007e-02,  4.9222e-01,
#           -1.5266e-01, -3.7637e-01,  1.6831e-01, -1.5246e-01, -1.7899e-01,
#           -3.1363e-01, -3.0271e-01,  1.0807e-01,  1.5037e-01, -9.7010e-02,
#            6.0834e-04,  3.0621e-02,  4.2494e-03,  6.1245e-02, -2.7367e-01,
#            3.5483e-02, -3.9043e-01,  5.1445e-01, -1.0435e-01, -2.2719e-02,
#            7.7455e-02, -4.0701e-02, -9.8863e-02, -6.9596e-02,  5.2220e-02,
#            5.1546e-01,  1.7538e-01, -2.3545e-01, -2.3639e-01, -1.6724e-01,
#           -1.8221e-02, -2.1833e-01,  5.3910e-01, -9.1881e-03, -6.6498e-01,
#            1.0546e-01,  9.1540e-02, -1.8458e-01, -7.1557e-01, -3.9438e-01,
#            2.0321e-01, -1.1172e-01,  2.1504e-01,  2.6272e-01,  2.2637e-01,
#           -2.3403e-02, -2.1096e-01, -1.5859e-01, -2.7243e-02, -1.3774e-01,
#            3.4014e-02, -3.5716e-02, -1.1084e-02,  2.1196e-01,  2.3701e-01,
#           -1.6988e-01, -4.5448e-02,  5.6395e-02,  1.2687e-01, -6.8383e-02,
#           -4.2193e-01,  2.5917e-01, -3.2169e-01, -7.6191e-02,  1.2374e-01,
#           -1.7020e-01,  1.1202e-01,  9.8462e-01,  2.0026e-01,  1.4958e-02,
#           -1.3465e-01, -1.1441e-01,  1.4483e-01,  3.9669e-01,  3.5137e-02,
#           -6.4338e-02, -2.4342e-02, -4.0742e-02, -8.7151e-03, -2.5696e-01,
#            5.0392e-01, -5.9998e-02,  2.0297e-01,  5.6498e-01,  1.2140e-01,
#            2.9459e-01,  4.4165e-02, -7.1877e-02, -2.0842e-01,  6.8380e-02,
#           -1.1225e-01,  1.6539e-01,  4.3321e-02, -1.4596e-01,  2.4069e-01,
#            4.4686e-01,  8.1265e-02,  5.0732e-01,  1.2134e-01,  1.0933e-01,
#            1.2570e-01,  7.6670e-02,  7.8666e-02, -4.9002e-02, -4.2305e-01,
#            5.0120e-01,  5.1186e-02,  2.1434e-01, -4.7962e-02,  6.4073e-01,
#            2.7222e-01,  1.2464e-01, -4.6426e-01,  1.1079e-01,  1.1389e-02,
#            1.5924e+00,  1.9424e-01,  1.7039e-01, -1.1733e-01,  4.2440e-01,
#           -2.3526e-01, -1.7836e-01,  1.1936e-01, -2.6800e-01,  5.8646e-03,
#            1.0145e-01,  1.3495e-01,  3.0408e-01, -2.3402e-01,  3.5391e-02,
#            1.5180e-01, -9.3938e-02,  5.2215e-03,  1.0790e-01, -1.1037e-01,
#           -3.5627e-01, -1.3146e+00, -4.8254e-02, -5.9793e-02, -2.4905e-02,
#            1.8161e-01,  1.8688e-01, -1.0028e-01,  4.5409e-02,  3.6992e-01,
#            2.0989e-01,  2.2494e-01, -1.3366e-01,  1.7329e-01,  1.2916e-01,
#            3.6740e-03, -1.1405e-01,  3.4990e-02,  1.6451e-02,  5.4374e-01,
#           -2.3220e-01,  4.7579e-02,  1.7938e-01, -6.6151e-01, -3.2563e-01,
#            9.6450e-02,  3.0209e-01, -2.3658e-01,  5.3855e-01, -6.8250e-02,
#            3.3007e-01, -2.1496e-01,  2.8996e-03,  5.9490e-02, -9.6012e-02,
#           -2.8618e-02,  2.6638e-01, -2.2581e-01,  3.2112e-02,  7.7309e-02,
#           -4.3330e-01, -3.7903e-01,  2.2244e-02, -1.0196e-01, -5.1435e-01,
#            1.3021e-02, -2.0359e-01,  2.1322e-01, -1.0053e-01, -3.9056e-01,
#           -5.5279e+00, -2.7655e-01, -1.6345e-01, -4.8555e-01,  1.9936e-02,
#           -2.3449e-01, -3.1698e-01, -2.6793e-01, -6.7941e-01,  9.8048e-02,
#           -3.1380e-01,  3.4003e-01,  1.6246e-01,  1.4157e-01, -3.8648e-01,
#           -7.5587e-02,  1.0251e-01,  5.2086e-02,  2.5438e-01,  4.7001e-01,
#            8.5717e-02, -2.3493e-01, -3.0509e-01,  2.2606e-01,  5.0955e-02,
#            5.7338e-02,  7.0562e-03,  7.4777e-02, -1.0279e+00, -1.8918e-01,
#            1.8638e-01, -3.4537e-01, -3.6041e-01, -1.3962e-01, -1.8805e-01,
#           -5.5246e-02,  9.5287e-02,  1.5054e-01, -1.2067e-01, -6.6494e-02,
#            1.6793e-01,  6.9252e-02,  2.6410e-01, -1.0630e-01, -5.1233e-01,
#            1.1810e-01,  9.0163e-02,  2.0988e-01,  2.2023e-01,  2.0948e-01,
#            9.2799e-02, -1.0001e-01,  3.5878e-01,  1.7129e+00, -1.5656e-01,
#            1.5116e-01,  1.6037e-01, -4.0525e-01,  8.2433e-02, -1.9864e-01,
#            2.4217e-01, -2.1470e-02,  7.4909e-03,  3.1467e-01,  1.6700e-01,
#            9.7403e-02,  4.1119e-02, -2.4092e+00, -1.3004e-01, -1.4268e-01,
#           -9.3518e-03,  4.8391e-01,  2.6310e-01,  3.6449e-02, -1.4097e-01,
#            8.6635e-02,  1.7788e-01, -3.7172e-01,  2.0455e-01, -8.7495e-02,
#            2.2947e-01,  3.1079e-02, -1.5053e-01,  2.8377e-01, -1.2311e-01,
#           -4.6380e-01,  2.9973e-01, -4.6844e-01, -5.2543e-02,  9.1567e-02,
#           -3.6689e-01, -1.6356e-01,  7.0353e-02,  1.4044e-01, -1.9800e-01,
#            3.7971e-01,  3.9460e-01, -2.9721e-01,  7.2676e-02,  2.7820e-01,
#            1.5614e-02, -2.0810e-01, -3.1927e-01, -2.1293e-01,  2.0291e-03,
#            1.3738e-01,  1.5887e-01,  1.5354e-01,  3.7776e-01,  1.2191e-01,
#           -2.7037e-01,  2.9423e-01, -1.1793e-01,  3.6262e-01,  9.1001e-02,
#            7.7056e-02, -9.1430e-02, -1.7146e-01,  4.6282e-01,  1.9776e-03,
#           -2.0808e-01, -5.3908e-01,  2.2146e-01, -5.6588e-02, -3.0137e-01,
#           -1.3361e-02,  1.0077e-01, -2.0917e-01, -1.9636e-01,  9.8350e-02,
#           -9.2220e-02,  5.0323e-03, -1.9768e-01, -3.2962e-01,  1.0032e-01,
#            1.0144e-01, -1.1809e-01, -7.5203e-02, -3.3606e-03,  9.2703e-02,
#            3.4710e-01,  9.1115e-02, -6.5222e-01, -2.8761e-01, -4.1978e-01,
#            2.2312e-01, -1.4472e-02, -7.8023e-02, -3.0923e-02,  2.0670e-01,
#            4.3984e-02,  1.2458e-02, -9.5902e-02, -1.9393e-01,  1.6599e-01,
#            9.5790e-02,  9.1231e-02, -5.8473e-01, -2.1481e-01,  5.5690e-02,
#            2.3599e-01, -8.0764e-02,  4.3337e-01, -9.9496e-02, -5.7681e-02,
#           -2.7871e-01, -4.0877e-01,  2.6964e-01,  1.4529e-01,  3.1422e-01,
#            1.3161e-01, -2.5086e-01, -1.4132e-01, -3.1637e-01,  1.7101e-01,
#           -1.7328e-01, -9.4101e-02, -5.3423e-01, -2.8390e-01,  3.8250e-01,
#           -3.7281e-01, -6.6108e-02,  3.8179e-02, -5.5958e-02,  9.2580e-02,
#           -7.1125e-02, -2.1326e-01,  4.3088e-02, -2.2195e-01, -2.1630e-01,
#           -4.7983e-02, -4.9319e-02,  1.6974e-01,  1.4272e-01,  1.9323e-01,
#           -3.8083e-01,  2.6979e-02,  5.5928e-01, -1.1065e-01, -1.1865e-01,
#            1.9037e-01, -3.9308e-01, -1.4658e-02, -1.7365e-01, -1.8720e-01,
#           -3.2307e-01, -8.4726e-02,  2.3025e-01,  3.6570e-01, -3.2306e-01,
#            1.3804e-02, -3.1396e-01, -4.1607e-01, -2.9079e-01, -4.0768e-01,
#            7.4628e-01, -1.5015e-01,  3.4709e-02, -1.6030e-02,  1.5649e-01,
#           -4.3430e-01, -1.2073e-01, -2.4807e-02, -4.0001e-01, -2.8723e-01,
#           -3.2512e-01, -5.7920e-01, -8.9082e-02,  8.5947e-02,  1.6296e-01,
#            4.3660e-01, -4.6669e-01, -1.0081e-01,  1.0880e-01,  1.3812e-01,
#            2.1717e-01, -3.2594e-01,  1.3245e-01, -1.0798e-01,  3.3152e-01,
#           -6.9854e-03, -3.2855e-02, -2.1524e-01,  3.1785e-01, -1.6065e-01,
#            1.4953e-01, -2.5060e-02,  3.3671e-01, -1.5572e-01,  5.7614e-01,
#           -2.5506e-01,  2.0724e-01,  6.5889e-02, -3.8290e-02, -2.4639e-01,
#           -1.5379e-01, -2.6265e-01, -4.3974e-01, -2.6098e-01, -5.0482e-02,
#            3.7788e-01, -2.1272e-02, -3.5386e-01,  1.2479e-01,  2.0043e-01,
#           -1.0090e-01, -5.5552e-02, -7.1258e-02,  6.7696e-01, -5.8505e-01,
#           -3.1477e-02, -9.3871e-02,  4.2118e-01, -4.6134e-01, -3.6563e-02,
#           -3.3061e-01,  9.9769e-02,  1.2202e-01,  1.2963e-01, -2.2720e-01,
#           -2.9332e-01, -2.4938e-02]]])

# %%
print("min style_anchor", torch.min(style_anchor[0]))
print("max style_anchor", torch.max(style_anchor[0]))
# Out:
# min style_anchor tensor(-6.1928)
# max style_anchor tensor(1.7304)

# %%
print("min negative_anchor", torch.min(negative_anchor[0]))
print("max negative_anchor", torch.max(negative_anchor[0]))
# Out:
# min negative_anchor tensor(-5.5279)
# max negative_anchor tensor(1.7129)

# %%
try:
    model, preprocess_train, preprocess_val = open_clip.create_model_and_transforms('hf-hub:Marqo/marqo-fashionCLIP')
    tokenizer = open_clip.get_tokenizer('hf-hub:Marqo/marqo-fashionCLIP')
    model = model.to(config.DEVICE)
except Exception as e:
    raise RuntimeError(f"❌ Failed to load FashionCLIP model: {e}")

# %%
def build_image_embedding_database(image_files):
    embeddings = {}
    for file in image_files:
        path = os.path.join(config.TEST_DIR, file)
        img = Image.open(path).convert("RGB")
        img_tensor = preprocess_val(img).unsqueeze(0).to(config.DEVICE)
        with torch.no_grad(), torch.amp.autocast(device_type='mps'):
            embedding = model.encode_image(img_tensor).to(config.DEVICE)
        embeddings[path] = embedding
    return embeddings

def build_metadata_embedding_database(image_files):
    embeddings = {}
    for file in image_files:
        path = os.path.join(config.TEST_DIR, file)
        img = Image.open(path).convert("RGB")
        img_tensor = preprocess_val(img).unsqueeze(0).to(config.DEVICE)
        with torch.no_grad(), torch.amp.autocast(device_type='mps'):
            embedding = model.encode_image(img_tensor).to(config.DEVICE)
        embeddings[path] = embedding
    return embeddings

# %%
def embed_text(text_content):
    tokens = tokenizer(text_content).to(config.DEVICE)
    with torch.no_grad(), torch.amp.autocast(device_type="mps"):
        embedding = model.encode_text(tokens).to(config.DEVICE)
    return embedding

# %%
def update_user_anchor(current_anchor, new_like_path, alpha=0.3):
    img = Image.open(new_like_path).convert("RGB")
    img_tensor = preprocess_val(img).unsqueeze(0).to(config.DEVICE)
    with torch.no_grad(), torch.amp.autocast(device_type='mps'):
        embedding = model.encode_image(img_tensor).to(config.DEVICE)

    new_embed = F.normalize(embedding, dim=1)
    updated_anchor = F.normalize((1 - alpha) * current_anchor + alpha * new_embed, dim=1)
    return updated_anchor

# %%
# Optional: map score from [-1, 1] to [0, 1]
def rescale(x):
    return (x + 1) / 2

# %%
def score_image(image_embedding, anchor, neg_anchor=None, context_text=None):
    image_embedding = F.normalize(image_embedding, dim=-1)
    anchor = F.normalize(anchor, dim=-1)
    pos_score = F.cosine_similarity(image_embedding, anchor, dim=-1).item() # calculates the cosine similarity along the last dimension
    final_score = pos_score # calculates how similar the image is to the anchor

    if neg_anchor is not None:
        neg_anchor = F.normalize(neg_anchor, dim=-1)
        neg_score = F.cosine_similarity(image_embedding, neg_anchor, dim=-1).item()
        final_score = pos_score - neg_score

    if context_text is not None:
        text_embedding = embed_text(context_text)
        text_embedding = F.normalize(text_embedding, dim=-1)
        text_score = F.cosine_similarity(image_embedding, text_embedding, dim=-1).item()
        # Soft gate for text impact
        beta = torch.sigmoid(torch.tensor(pos_score - text_score))
        final_score = beta * final_score + (1 - beta) * text_score


    return rescale(final_score)

# %%
test_image_files = [
    f for f in os.listdir(config.TEST_DIR)
    if f.lower().endswith(config.IMAGE_FILE_EXTENSIONS)
]

test_image_files.sort()

embeddings = build_image_embedding_database(test_image_files)
scores = {}
score_threshold = 0.5

# %%
print(type(embeddings))
print(type(embeddings[list(embeddings.keys())[0]]))
# Out:
# <class 'dict'>
# <class 'torch.Tensor'>

# %%
correct_count = 0
faulty_count = 0

for image_path, embedding in embeddings.items():
    embedding = embedding.to(config.DEVICE)
    style_anchor = style_anchor.to(config.DEVICE)
    score = score_image(embedding, style_anchor)
    scores[image_path] = score

    print(f"Image: {image_path}")
    print(f"Personalized score: {score:.4f}")

    # Condition checks
    if (score > score_threshold and 'good' in image_path) or \
       (score < score_threshold and 'bad' in image_path):
        print("classification correct\n")
        correct_count += 1
    else:
        print("classification faulty\n")
        faulty_count += 1

not_rated = 0

# Final summary
print(f"Total correct classifications: {correct_count} out of {correct_count + faulty_count - not_rated} ({correct_count / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
print(f"Total faulty classifications: {faulty_count - not_rated} out of {correct_count + faulty_count - not_rated} ({(faulty_count - not_rated) / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
# Out:
# Image: ../../data/outfits/outfits_to_test/10_good_o.jpg
# Personalized score: 0.7930
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/11_good_o.jpg
# Personalized score: 0.7405
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/12_good_o.jpg
# Personalized score: 0.7377
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/13_bad_o.jpg
# Personalized score: 0.6924
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/14_bad_o.jpg
# Personalized score: 0.6558
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/15_good_o.jpg
# Personalized score: 0.7951
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/16_good_o.jpg
# Personalized score: 0.7755
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/17_bad_o.jpg
# Personalized score: 0.7908
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/18_bad_o.jpg
# Personalized score: 0.7928
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/19_good_o.jpg
# Personalized score: 0.8589
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_o.jpg
# Personalized score: 0.8202
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_s.jpg
# Personalized score: 0.8359
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/20_good_o.jpg
# Personalized score: 0.7415
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/21_bad_o.jpg
# Personalized score: 0.6688
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/22_good_o.jpg
# Personalized score: 0.8036
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/23_bad_o.jpg
# Personalized score: 0.7935
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/24_bad_o.jpg
# Personalized score: 0.7830
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/25_good_o.jpg
# Personalized score: 0.7625
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/26_bad_o.jpg
# Personalized score: 0.7240
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/27_good_o.jpg
# Personalized score: 0.7594
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/28_bad_o.jpg
# Personalized score: 0.7592
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/29_bad_o.jpg
# Personalized score: 0.7099
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_o.jpg
# Personalized score: 0.7957
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_s.jpg
# Personalized score: 0.8509
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/30_bad_o.jpg
# Personalized score: 0.7239
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/31_good_o.jpg
# Personalized score: 0.7717
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/32_good_o.jpg
# Personalized score: 0.6576
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/33_bad_o.jpg
# Personalized score: 0.8011
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/34_good_o.jpg
# Personalized score: 0.7736
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/35_good_o.jpg
# Personalized score: 0.7550
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_o.jpg
# Personalized score: 0.7578
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/3_bad_s.jpg
# Personalized score: 0.7978
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/5_bad_o.jpg
# Personalized score: 0.7647
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/5_bad_s.jpg
# Personalized score: 0.8089
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/6_good_o.jpg
# Personalized score: 0.8076
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_s.jpg
# Personalized score: 0.8248
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_o.jpg
# Personalized score: 0.7710
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/7_bad_s.jpg
# Personalized score: 0.8101
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/8_bad_o.jpg
# Personalized score: 0.6922
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/9_good_o.jpg
# Personalized score: 0.7373
# classification correct
#
# Total correct classifications: 19 out of 40 (47.50%)
# Total faulty classifications: 21 out of 40 (52.50%)

# %%
correct_count = 0
faulty_count = 0

for image_path, embedding in embeddings.items():
    embedding = embedding.to(config.DEVICE)
    style_anchor = style_anchor.to(config.DEVICE)
    negative_anchor = negative_anchor.to(config.DEVICE)
    score = score_image(embedding, style_anchor, negative_anchor)
    scores[image_path] = score

    print(f"Image: {image_path}")
    print(f"Personalized score: {score:.4f}")

    # Condition checks
    if (score > score_threshold and 'good' in image_path) or \
       (score < score_threshold and 'bad' in image_path):
        print("classification correct\n")
        correct_count += 1
    else:
        print("classification faulty\n")
        faulty_count += 1

not_rated = 0

# Final summary
print(f"Total correct classifications: {correct_count} out of {correct_count + faulty_count - not_rated} ({correct_count / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
print(f"Total faulty classifications: {faulty_count - not_rated} out of {correct_count + faulty_count - not_rated} ({(faulty_count - not_rated) / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
# Out:
# Image: ../../data/outfits/outfits_to_test/10_good_o.jpg
# Personalized score: 0.4949
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/11_good_o.jpg
# Personalized score: 0.5185
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/12_good_o.jpg
# Personalized score: 0.5211
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/13_bad_o.jpg
# Personalized score: 0.4942
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/14_bad_o.jpg
# Personalized score: 0.4950
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/15_good_o.jpg
# Personalized score: 0.4882
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/16_good_o.jpg
# Personalized score: 0.4641
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/17_bad_o.jpg
# Personalized score: 0.4919
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/18_bad_o.jpg
# Personalized score: 0.5010
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/19_good_o.jpg
# Personalized score: 0.5521
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_o.jpg
# Personalized score: 0.5267
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_s.jpg
# Personalized score: 0.5112
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/20_good_o.jpg
# Personalized score: 0.5166
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/21_bad_o.jpg
# Personalized score: 0.4989
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/22_good_o.jpg
# Personalized score: 0.5052
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/23_bad_o.jpg
# Personalized score: 0.5201
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/24_bad_o.jpg
# Personalized score: 0.4952
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/25_good_o.jpg
# Personalized score: 0.4690
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/26_bad_o.jpg
# Personalized score: 0.5105
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/27_good_o.jpg
# Personalized score: 0.5185
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/28_bad_o.jpg
# Personalized score: 0.4741
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/29_bad_o.jpg
# Personalized score: 0.5071
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_o.jpg
# Personalized score: 0.4763
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/2_bad_s.jpg
# Personalized score: 0.4772
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/30_bad_o.jpg
# Personalized score: 0.5116
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/31_good_o.jpg
# Personalized score: 0.5229
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/32_good_o.jpg
# Personalized score: 0.4822
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/33_bad_o.jpg
# Personalized score: 0.4812
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/34_good_o.jpg
# Personalized score: 0.5151
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/35_good_o.jpg
# Personalized score: 0.4991
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/3_bad_o.jpg
# Personalized score: 0.4680
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_s.jpg
# Personalized score: 0.4576
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/5_bad_o.jpg
# Personalized score: 0.4753
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/5_bad_s.jpg
# Personalized score: 0.4654
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_o.jpg
# Personalized score: 0.5099
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_s.jpg
# Personalized score: 0.5130
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_o.jpg
# Personalized score: 0.4696
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_s.jpg
# Personalized score: 0.4578
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/8_bad_o.jpg
# Personalized score: 0.4632
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/9_good_o.jpg
# Personalized score: 0.5075
# classification correct
#
# Total correct classifications: 29 out of 40 (72.50%)
# Total faulty classifications: 11 out of 40 (27.50%)

# %%
correct_count = 0
faulty_count = 0

for image_path, embedding in embeddings.items():
    embedding = embedding.to(config.DEVICE)
    style_anchor = style_anchor.to(config.DEVICE)
    negative_anchor = negative_anchor.to(config.DEVICE)
    score = score_image(embedding, style_anchor, negative_anchor, "A chic, elegant outfit")
    scores[image_path] = score

    class_names = ['bad', 'good']  # 0=negative, 1=positive
    print(f"Image: {image_path}")
    print(f"Personalized score: {score:.4f}")

    # Condition checks
    if (score > score_threshold and 'good' in image_path) or \
       (score < score_threshold and 'bad' in image_path):
        print("classification correct\n")
        correct_count += 1
    else:
        print("classification faulty\n")
        faulty_count += 1

not_rated = 0

# Final summary
print(f"Total correct classifications: {correct_count} out of {correct_count + faulty_count - not_rated} ({correct_count / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
print(f"Total faulty classifications: {faulty_count - not_rated} out of {correct_count + faulty_count - not_rated} ({(faulty_count - not_rated) / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
# Out:
# Image: ../../data/outfits/outfits_to_test/10_good_o.jpg
# Personalized score: 0.5306
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/11_good_o.jpg
# Personalized score: 0.5343
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/12_good_o.jpg
# Personalized score: 0.5375
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/13_bad_o.jpg
# Personalized score: 0.5336
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/14_bad_o.jpg
# Personalized score: 0.5242
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/15_good_o.jpg
# Personalized score: 0.5350
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/16_good_o.jpg
# Personalized score: 0.5174
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/17_bad_o.jpg
# Personalized score: 0.5374
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/18_bad_o.jpg
# Personalized score: 0.5370
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/19_good_o.jpg
# Personalized score: 0.5736
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_o.jpg
# Personalized score: 0.5474
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_s.jpg
# Personalized score: 0.5258
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/20_good_o.jpg
# Personalized score: 0.5413
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/21_bad_o.jpg
# Personalized score: 0.5155
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/22_good_o.jpg
# Personalized score: 0.5377
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/23_bad_o.jpg
# Personalized score: 0.5421
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/24_bad_o.jpg
# Personalized score: 0.5303
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/25_good_o.jpg
# Personalized score: 0.5128
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/26_bad_o.jpg
# Personalized score: 0.5427
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/27_good_o.jpg
# Personalized score: 0.5465
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/28_bad_o.jpg
# Personalized score: 0.5307
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/29_bad_o.jpg
# Personalized score: 0.5327
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_o.jpg
# Personalized score: 0.5198
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_s.jpg
# Personalized score: 0.5125
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/30_bad_o.jpg
# Personalized score: 0.5404
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/31_good_o.jpg
# Personalized score: 0.5575
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/32_good_o.jpg
# Personalized score: 0.5431
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/33_bad_o.jpg
# Personalized score: 0.5153
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/34_good_o.jpg
# Personalized score: 0.5345
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/35_good_o.jpg
# Personalized score: 0.5247
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_o.jpg
# Personalized score: 0.5171
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/3_bad_s.jpg
# Personalized score: 0.4969
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/5_bad_o.jpg
# Personalized score: 0.5243
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/5_bad_s.jpg
# Personalized score: 0.5080
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/6_good_o.jpg
# Personalized score: 0.5383
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_s.jpg
# Personalized score: 0.5359
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_o.jpg
# Personalized score: 0.5165
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/7_bad_s.jpg
# Personalized score: 0.4927
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/8_bad_o.jpg
# Personalized score: 0.5087
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/9_good_o.jpg
# Personalized score: 0.5355
# classification correct
#
# Total correct classifications: 21 out of 40 (52.50%)
# Total faulty classifications: 19 out of 40 (47.50%)

# %%
# Load user likes and dislikes (metadata)
liked_metadata_embeddings = load_metadata_embeddings_from_dir(config.EMBEDDINGS_METADATA_POS_OUTFITS_DIR)
disliked_metadata_embeddings = load_metadata_embeddings_from_dir(config.EMBEDDINGS_METADATA_NEG_OUTFITS_DIR)

# %%
print(liked_metadata_embeddings.shape)
print(disliked_image_embeddings.shape)
# Out:
# torch.Size([816, 1, 512])
# torch.Size([4531, 1, 512])

# %%
print("Sample image embedding:", liked_image_embeddings[0][:10])
print("Sample metadata embedding:", liked_metadata_embeddings[0][:10])
print("Unique metadata values:", torch.unique(liked_metadata_embeddings))
# Out:
# Sample image embedding: tensor([[ 6.5039e-01, -7.1167e-02,  3.8184e-01,  1.6982e+00,  4.9048e-01,
#           3.8159e-01, -4.5357e-03, -1.7847e-01,  8.6670e-01,  1.4526e-01,
#          -1.3843e-01,  2.0996e-01,  1.6504e-01, -2.8442e-01,  6.2256e-01,
#          -1.6968e-02,  2.0435e-01,  7.1045e-02, -2.6538e-01,  2.0776e-01,
#          -5.0244e-01, -4.4653e-01, -1.0187e-01, -1.8809e+00,  5.3857e-01,
#          -2.6880e-01,  1.8110e-03,  6.9531e-01,  6.5625e-01,  5.6299e-01,
#           2.1118e-01,  1.0841e-02, -8.1299e-01, -3.9844e-01, -1.9727e-01,
#           3.6206e-01,  1.3403e-01,  5.6689e-01,  4.2017e-01, -2.5562e-01,
#          -5.3711e-01,  2.3254e-01, -5.6494e-01, -5.3271e-01,  4.1333e-01,
#           2.9053e-01, -3.6035e-01,  3.5425e-01, -7.6465e-01, -1.5225e+00,
#          -1.0469e+00, -4.7144e-01, -2.6904e-01, -6.0840e-01,  1.8811e-01,
#          -5.4443e-01, -4.3506e-01, -3.4009e-01,  1.5918e-01, -5.6689e-01,
#           4.1809e-02, -2.9572e-02,  7.7588e-01, -1.1359e-01, -4.2542e-02,
#          -1.5491e-01,  3.1714e-01, -5.6934e-01,  7.3303e-02,  4.3115e-01,
#           1.5735e-01, -2.5439e-01, -9.1406e-01,  2.2070e-01, -7.0068e-01,
#          -4.2969e-02, -4.8511e-01,  1.0732e+00, -2.4329e-01, -7.2559e-01,
#           2.5073e-01,  1.4697e-01, -6.1523e-02, -5.1123e-01, -2.9907e-01,
#          -1.1713e-01,  1.7273e-01,  6.0938e-01,  4.2285e-01,  5.3418e-01,
#           8.7988e-01, -2.3877e-01, -2.9614e-01,  1.0309e-01,  1.7334e-01,
#          -4.5715e-02,  1.6040e-01, -6.9189e-01, -9.6069e-02, -1.2871e+00,
#          -2.7368e-01,  2.7710e-02,  9.3323e-02, -3.8208e-02, -5.1562e-01,
#          -1.4783e-01,  4.1504e-01,  4.9530e-02, -8.5791e-01,  1.0425e-01,
#           5.8301e-01, -6.4575e-02,  9.3652e-01,  8.3557e-02,  1.2695e-01,
#           1.4844e-01, -4.8877e-01,  4.6387e-01,  2.6660e-01,  1.1182e-01,
#           6.2695e-01, -5.0830e-01,  4.2505e-01,  1.3416e-01, -1.0820e+00,
#           8.0322e-01,  3.9893e-01, -1.8982e-01,  2.1594e-01,  1.5587e-02,
#           4.0942e-01,  3.0981e-01, -2.4582e-02, -3.6426e-01,  5.5664e-01,
#           6.1737e-02, -2.9004e-01, -7.2327e-02, -2.9761e-01,  2.5439e-01,
#           4.5654e-01, -5.4626e-02,  1.0846e-01, -8.6328e-01, -8.5645e-01,
#          -2.0618e-01, -3.4790e-03, -1.9592e-01, -2.9150e-01, -6.9092e-01,
#           3.4570e-01,  5.3009e-02, -4.6661e-02, -1.9434e-01,  7.4158e-02,
#           3.7500e-01,  1.5225e+00, -1.0244e+00, -4.0527e-01, -4.2456e-01,
#           1.6582e+00,  8.5876e-02,  1.0547e-01, -6.3232e-01,  9.7070e-01,
#          -3.6377e-01, -5.0049e-01, -1.6006e-02, -2.3071e-01,  4.8920e-02,
#          -1.1707e-01,  1.5343e-02, -9.4238e-01, -3.3740e-01,  2.3865e-02,
#           8.3789e-01, -3.0835e-01,  1.1084e-01,  6.7688e-02, -2.6318e-01,
#          -4.1382e-01, -5.5127e-01,  4.4458e-01, -6.4160e-01, -5.5957e-01,
#          -6.8750e-01, -1.1986e-02, -1.1102e-01,  2.1228e-01,  1.0078e+00,
#          -6.1157e-02,  2.3096e-01, -3.3301e-01,  3.3594e-01, -3.3423e-01,
#           1.6248e-01,  1.5759e-01, -3.0029e-01,  1.2659e-01,  4.4800e-01,
#          -1.7212e-01, -1.7773e-01,  2.4463e-01, -6.8262e-01, -2.3438e-01,
#           6.7969e-01,  4.9805e-01,  3.4863e-01,  2.2461e+00, -1.5979e-01,
#           8.7402e-02, -2.3169e-01,  9.0723e-01,  6.2158e-01,  4.0588e-02,
#          -3.5938e-01,  9.7534e-02, -6.7627e-02,  8.5815e-02, -8.3313e-02,
#          -5.9033e-01,  6.5479e-01,  1.7383e-01, -6.1475e-01, -8.2825e-02,
#           1.8103e-01,  4.6509e-01,  4.7583e-01, -3.2129e-01, -3.7207e-01,
#          -6.0703e+00,  3.3203e-01,  2.2278e-01, -1.1992e+00, -4.4971e-01,
#           9.1162e-01, -5.0293e-01,  5.7587e-02, -1.3535e+00, -2.2681e-01,
#          -3.9502e-01,  4.3628e-01, -4.8256e-03, -1.9177e-01, -4.5850e-01,
#           1.6052e-01, -1.1224e-01,  2.1439e-02,  1.6455e-01,  1.1353e-02,
#           1.6687e-01, -5.4590e-01,  1.2183e-01,  2.7417e-01, -2.7368e-01,
#          -7.0801e-01,  1.2848e-02,  5.3125e-01, -1.7217e+00, -2.5986e-02,
#          -4.8309e-02, -3.2300e-01, -7.2852e-01, -3.3740e-01,  1.6577e-01,
#          -5.3589e-02,  4.9414e-01,  8.9661e-02, -2.8275e-02,  3.0713e-01,
#           4.4482e-01,  2.7075e-01,  2.8247e-01, -3.5620e-01, -2.2717e-01,
#           1.4233e-01, -3.0811e-01,  5.2832e-01,  1.2891e-01,  7.6843e-02,
#          -1.4294e-01, -1.0381e+00,  2.5787e-02,  2.1172e+00,  2.9125e-03,
#          -1.4008e-02, -8.6792e-02,  3.6224e-02,  2.6562e-01,  4.3042e-01,
#          -5.0098e-01, -1.7493e-01, -5.4291e-02,  4.0845e-01, -6.1523e-02,
#           2.5146e-01,  2.7734e-01, -2.6973e+00, -3.6841e-01, -6.2347e-02,
#           1.0176e+00,  6.4307e-01,  3.2178e-01, -3.0933e-01, -5.7422e-01,
#           6.0547e-01,  1.6467e-01,  3.0762e-02,  1.8701e-01,  1.7322e-01,
#          -3.4766e-01, -6.2842e-01, -7.3633e-01,  4.2676e-01, -4.4214e-01,
#          -7.1387e-01,  3.4912e-01, -1.6172e+00,  2.9199e-01,  7.4609e-01,
#          -5.3027e-01, -3.6401e-01, -8.4412e-02,  1.4587e-01, -5.1318e-01,
#           4.9896e-02,  2.7979e-01,  1.8213e-01, -4.6356e-02,  5.3320e-01,
#          -3.5583e-02,  3.4619e-01, -4.4128e-02, -6.0254e-01, -6.5039e-01,
#           3.7329e-01, -2.1558e-01,  2.9907e-01,  9.0332e-02,  8.2275e-02,
#          -5.1318e-01,  4.0161e-01,  2.9175e-01,  6.2927e-02, -1.5411e-03,
#           1.1359e-01, -3.1055e-01, -4.2041e-01,  7.3730e-01,  5.5420e-01,
#          -4.3994e-01, -7.4170e-01,  1.9141e-01,  3.8989e-01, -3.3374e-01,
#           1.7419e-01, -5.6445e-01, -1.9946e-01, -3.0029e-01,  7.1387e-01,
#           3.9575e-01, -1.7688e-01, -4.3628e-01, -8.3496e-01,  7.4219e-01,
#          -6.7578e-01,  3.9722e-01, -2.1805e-02,  6.6406e-02,  4.5850e-01,
#           1.0541e-01,  5.4736e-01, -6.9385e-01, -2.5195e-01, -3.7781e-02,
#           4.0479e-01, -1.3135e-01,  4.7241e-01, -5.4053e-01,  1.5833e-01,
#          -4.1748e-01, -6.9238e-01, -3.5400e-01, -4.0649e-01,  2.1570e-01,
#          -1.8323e-01,  5.5713e-01, -7.1875e-01, -3.1763e-01, -4.4238e-01,
#          -8.0811e-01, -1.5845e-01,  4.8218e-01, -1.2634e-01, -7.5879e-01,
#          -4.5349e-02, -4.2847e-01,  9.8206e-02, -6.0303e-02, -3.5620e-01,
#          -2.5366e-01,  2.4048e-01,  9.1309e-01, -5.5176e-01, -5.4102e-01,
#          -2.6587e-01,  3.7720e-01, -6.0059e-01,  3.7628e-02,  7.7002e-01,
#          -3.1177e-01, -5.2643e-02, -1.9238e-01,  9.5520e-02, -1.0109e-02,
#          -1.1261e-01, -5.6152e-02, -5.0830e-01,  2.3254e-01, -5.9326e-02,
#           2.3999e-01, -7.2021e-02, -9.6045e-01,  1.0895e-01,  6.0742e-01,
#           1.2189e-01,  4.6753e-01,  1.0602e-01,  2.2742e-01, -4.8633e-01,
#          -1.7651e-01, -1.9617e-01,  4.7559e-01, -3.6108e-01, -8.5449e-02,
#           1.3354e-01,  3.4149e-02, -1.4465e-01,  2.1082e-01, -1.7041e-01,
#          -1.7670e-02, -5.4980e-01, -1.1917e-02, -8.5840e-01, -1.2168e+00,
#           7.9541e-01, -7.6599e-02,  4.1113e-01,  7.4512e-01, -3.4473e-01,
#          -3.0298e-01,  7.5732e-01,  2.3669e-01, -2.6660e-01, -7.7197e-01,
#          -9.4666e-02, -7.9541e-01, -5.1025e-01,  4.0942e-01,  4.3945e-01,
#           3.4985e-01, -2.1411e-01, -4.8145e-01, -3.9160e-01,  6.5002e-02,
#          -1.4856e-01, -1.4294e-01,  5.0391e-01,  4.3457e-02, -7.9004e-01,
#           5.5811e-01,  2.0581e-01, -2.0959e-01, -8.5297e-03, -6.3574e-01,
#           1.3940e-01,  3.6816e-01,  7.3364e-02, -5.6299e-01, -1.0266e-01,
#          -2.8809e-01,  1.6162e-01, -5.5859e-01, -1.2915e-01, -8.5986e-01,
#          -2.3499e-01, -5.1318e-01, -1.7236e-01,  5.0391e-01,  3.2251e-01,
#           7.7393e-01,  3.2422e-01,  4.7803e-01, -7.0251e-02,  2.9443e-01,
#          -3.1769e-02, -5.0391e-01, -1.1005e-01,  7.5049e-01, -9.7705e-01,
#          -1.8359e-01, -2.1606e-01,  1.0508e+00, -6.3770e-01, -3.6792e-01,
#           1.1078e-01,  5.8936e-01,  4.1431e-01, -3.2251e-01, -5.9766e-01,
#          -7.9443e-01,  1.0199e-01]])
# Sample metadata embedding: tensor([[ 1.5820e-01, -3.7573e-01,  9.2871e-01,  9.6436e-01,  2.4646e-01,
#           3.6743e-01, -3.6597e-01,  1.8701e-01,  7.1094e-01, -3.9795e-01,
#           8.6182e-02, -4.4385e-01,  1.7871e-01, -3.5083e-01,  5.1465e-01,
#           1.1230e-01, -1.3403e-01, -2.2937e-01,  4.5947e-01,  3.1177e-01,
#          -7.0215e-01,  3.4607e-02,  2.7051e-01, -1.2524e-01,  6.8506e-01,
#           3.3057e-01,  2.0020e-01,  6.9458e-02,  1.8713e-01,  2.4719e-01,
#           2.0630e-01,  2.9785e-01, -4.0234e-01,  1.0986e-01, -1.0925e-01,
#           1.3855e-01, -4.9561e-01,  4.5337e-01,  7.2705e-01, -1.1060e-01,
#          -7.0361e-01, -4.7534e-01, -1.4331e-01, -9.4604e-02,  3.7744e-01,
#           2.5439e-01, -1.1353e-01,  3.0322e-01, -2.8491e-01, -1.3416e-01,
#          -9.1650e-01,  3.4888e-01,  5.3894e-02,  4.8120e-01, -1.6711e-01,
#          -9.0576e-02,  4.0771e-02,  3.6450e-01, -2.7563e-01,  7.9224e-02,
#          -3.1006e-01, -3.0371e-01,  4.3555e-01, -3.4888e-01, -7.7539e-01,
#           2.0117e-01, -3.6743e-01,  2.9907e-01, -3.6230e-01, -3.0249e-01,
#           3.3179e-01,  3.6523e-01, -3.3350e-01, -2.4365e-01, -2.7979e-01,
#           8.6670e-02, -1.4811e-03,  3.0518e-01, -6.8652e-01, -4.9292e-01,
#          -6.6528e-02, -1.2952e-01, -2.5513e-01, -3.1834e-03,  4.0576e-01,
#          -4.3060e-02,  6.7236e-01,  8.7585e-02, -5.3711e-01,  4.7437e-01,
#          -7.6416e-02, -2.4854e-01,  7.8369e-01, -4.3793e-02,  3.4717e-01,
#           4.0207e-03, -1.1481e-01, -4.2236e-01, -3.0981e-01, -9.4629e-01,
#          -1.9531e-01, -2.3206e-01, -5.1300e-02, -2.6099e-01,  6.4941e-01,
#          -7.8711e-01,  3.0103e-01, -1.0938e-01,  4.8714e-03, -6.2683e-02,
#          -5.0488e-01,  2.8125e-01,  2.8711e-01,  5.7520e-01, -2.0325e-01,
#          -2.3145e-01,  2.8394e-01,  7.1411e-02,  6.1737e-02,  6.5869e-01,
#          -2.9395e-01, -1.0779e-01, -5.3662e-01, -3.1665e-01, -2.3523e-01,
#           2.5854e-01,  6.7261e-02, -6.0547e-02,  7.8125e-01,  6.0059e-02,
#           9.3842e-03, -1.9263e-01, -1.8738e-01, -2.0618e-01,  2.5757e-01,
#           1.0327e-01,  5.6836e-01, -1.9800e-01,  2.7759e-01,  5.2100e-01,
#          -1.2659e-01, -2.7393e-01,  4.5142e-01,  4.9243e-01, -7.8125e-01,
#           8.2227e-01,  3.0469e-01, -3.7305e-01,  1.3354e-01, -5.6396e-01,
#          -1.0244e+00, -3.0737e-01,  3.2080e-01,  2.3877e-01,  9.4971e-02,
#          -2.3059e-01, -1.8347e-01, -3.4814e-01,  2.2327e-01,  1.3977e-01,
#           1.2306e-02, -6.8703e-03, -6.7041e-01, -7.7246e-01, -1.9821e-02,
#           5.7343e-02,  1.3025e-01, -3.6353e-01, -4.1162e-01,  1.0272e-01,
#          -3.8330e-01,  4.8071e-01,  2.5513e-01, -9.9426e-02,  6.2354e-01,
#           5.2032e-02, -2.7905e-01, -2.0218e-03,  1.1511e-01,  9.4482e-02,
#          -6.2012e-01,  7.0007e-02, -2.3694e-01,  6.9141e-01, -1.8823e-01,
#           5.9766e-01,  4.1089e-01,  4.8438e-01,  1.0332e+00, -7.3096e-01,
#          -1.7566e-01,  7.4097e-02,  6.0303e-01, -1.3684e-01,  5.6494e-01,
#           2.2900e-01, -2.3163e-02,  3.4961e-01,  5.3174e-01,  7.7271e-02,
#          -6.8176e-02, -3.8013e-01, -2.6782e-01,  1.2001e-02, -1.7102e-01,
#          -2.5635e-01, -5.4871e-02,  1.1438e-01,  1.4124e-01,  5.5847e-02,
#           4.0845e-01, -1.3123e-01, -3.1708e-02,  3.8696e-01,  9.2346e-02,
#          -4.7729e-02,  2.9614e-01, -1.1029e-01, -9.2725e-01,  3.0859e-01,
#          -3.7201e-02, -2.0923e-01, -4.8389e-01, -7.3877e-01, -1.4380e-01,
#          -1.5833e-01,  5.8398e-01,  1.2866e-01, -8.6731e-02, -3.5059e-01,
#          -6.3232e-01,  3.1201e-01,  3.7061e-01, -7.7148e-01,  8.9569e-03,
#          -1.6089e-01, -2.4658e-01,  2.4951e-01, -6.6162e-01, -3.0078e-01,
#          -3.0103e-01,  4.5386e-01,  3.3789e-01,  4.1064e-01,  1.2360e-01,
#          -1.4478e-01,  2.6880e-01, -2.2778e-01,  4.0332e-01,  6.1279e-01,
#           1.3721e-01, -1.3062e-01, -3.9893e-01, -2.6196e-01,  4.5020e-01,
#          -5.4395e-01, -4.7412e-01,  3.4692e-01, -3.7769e-01, -1.1665e-02,
#          -1.3440e-01, -2.0728e-01, -2.6758e-01,  5.7910e-01, -4.1016e-01,
#           1.3220e-01, -4.8047e-01, -2.1960e-01,  1.4893e-01,  3.5864e-01,
#           1.3806e-01,  3.2739e-01, -1.8359e-01,  2.0154e-01,  1.8359e-01,
#           2.1289e-01,  1.0010e-01, -9.9182e-02, -2.5488e-01, -3.0322e-01,
#           8.1604e-02, -8.0908e-01,  6.9287e-01,  6.5527e-01, -6.5723e-01,
#           6.6772e-02,  2.4585e-01, -1.5308e-01,  3.5986e-01, -7.3547e-02,
#           3.9697e-01,  9.5444e-03, -2.2498e-01,  7.5378e-02,  3.3862e-01,
#           3.0737e-01,  8.0017e-02, -4.9292e-01, -2.8992e-02,  1.4736e+00,
#          -9.6207e-03,  1.5784e-01,  2.3743e-01, -2.0129e-01,  1.3708e-01,
#           6.7676e-01,  4.4775e-01,  2.6318e-01, -2.8955e-01,  3.2990e-02,
#          -1.9885e-01, -2.2964e-02, -5.3906e-01, -2.5708e-01,  2.6782e-01,
#          -8.8232e-01,  1.5271e-01, -8.3057e-01,  4.0552e-01,  6.1035e-01,
#          -7.3486e-01, -1.0980e-01,  2.3938e-01,  1.8298e-01, -4.7266e-01,
#           1.6211e-01,  4.0234e-01,  8.9661e-02, -2.4951e-01, -6.3110e-02,
#          -6.0822e-02, -2.4609e-01,  3.6060e-01,  7.7881e-02,  8.0505e-02,
#          -1.5540e-01,  1.1938e-01, -1.6553e-01, -2.2192e-01,  5.6445e-01,
#          -2.5854e-01, -4.2676e-01, -8.6304e-02, -5.6030e-02,  5.5145e-02,
#           2.5439e-01,  6.6943e-01, -6.6406e-02, -8.1152e-01, -5.3809e-01,
#          -4.5142e-01,  3.8867e-01,  4.1333e-01,  4.0723e-01, -4.5776e-01,
#           1.5955e-01,  5.0293e-01,  2.8491e-01,  1.2988e-01, -3.6011e-01,
#          -1.3086e-01, -5.8594e-02,  5.5957e-01, -3.4149e-02,  3.6865e-01,
#          -7.6758e-01,  2.8711e-01, -3.6285e-02,  1.9885e-01,  4.0601e-01,
#           1.1371e-01, -6.6223e-02, -3.6621e-01, -8.0322e-01,  1.1609e-01,
#           1.0101e-01, -3.7939e-01, -8.1885e-01,  1.5930e-02, -6.2500e-01,
#           1.2366e-01,  4.9042e-02, -1.6602e-01,  2.5244e-01,  1.3403e-01,
#          -3.4888e-01,  1.6382e-01,  1.6571e-02,  7.5134e-02, -2.4292e-01,
#           2.1530e-02, -4.3213e-01,  1.3782e-01, -7.2217e-01,  9.1919e-02,
#           2.7173e-01,  2.6318e-01,  4.5923e-01,  1.9946e-01,  1.6235e-01,
#          -1.6785e-01, -2.2388e-01, -7.0129e-02, -4.1229e-02,  1.3049e-01,
#           4.0723e-01,  1.3940e-01,  2.6782e-01, -1.0193e-01,  5.6104e-01,
#          -1.0400e-01, -1.1389e-01,  9.0698e-02,  4.5947e-01,  8.1970e-02,
#          -2.0520e-01, -1.5613e-01, -1.7200e-01,  1.1292e-01, -3.7158e-01,
#           2.9126e-01, -8.0156e+00, -2.3697e-02,  2.9984e-02,  1.6675e-01,
#           2.3209e-02, -5.3320e-01,  2.2852e-01, -6.5430e-02,  7.6050e-02,
#          -2.1216e-01, -6.1377e-01,  4.6606e-01, -4.2578e-01, -2.5806e-01,
#          -4.4434e-02, -4.9103e-02,  1.7977e-03, -1.9495e-01, -1.0236e-01,
#          -4.5380e-02,  3.0426e-02, -2.4329e-01, -1.7603e-01, -1.1238e-02,
#           3.6841e-01,  1.7664e-01,  3.1470e-01,  2.3877e-01, -7.3975e-01,
#          -7.8320e-01, -8.8916e-01, -1.4734e-01, -2.5732e-01,  1.1833e-02,
#           3.1525e-02, -4.5630e-01,  4.5752e-01,  4.0674e-01,  6.3525e-01,
#           7.4219e-01, -1.4087e-01, -3.9093e-02,  2.8760e-01,  3.7671e-01,
#          -4.5459e-01, -1.2146e-01, -3.0533e-02, -1.9678e-01, -3.3643e-01,
#          -6.5479e-01,  4.6094e-01,  2.3584e-01,  4.1333e-01, -4.1479e-01,
#          -2.5439e-01, -4.7681e-01, -2.2974e-01, -1.0052e-01, -1.2817e-01,
#           6.0010e-01,  2.4658e-01, -1.2286e-01,  1.4856e-01,  1.6248e-01,
#          -3.8770e-01,  7.4387e-03, -5.1709e-01, -5.2686e-01,  2.7420e-02,
#           3.8916e-01, -2.9640e-03, -1.2183e-01,  2.5757e-02, -1.1993e-01,
#           7.1899e-02, -1.1237e-01,  2.4084e-01,  5.0244e-01,  1.0669e-01,
#           5.2344e-01,  2.2229e-01, -3.1738e-01, -5.3925e-02, -1.4661e-01,
#          -1.2494e-01, -1.9067e-01, -4.0356e-01,  3.7402e-01,  2.8290e-02,
#          -5.5023e-02,  5.7715e-01]], dtype=torch.float16)
# Unique metadata values: tensor([-10.2891, -10.2656, -10.1641,  ...,   1.8613,   1.8721,   2.0312],
#        dtype=torch.float16)

# %%
liked_joint = torch.cat([liked_image_embeddings, liked_metadata_embeddings], dim=0)
disliked_joint = torch.cat([disliked_image_embeddings, disliked_metadata_embeddings], dim=0)

style_anchor = torch.mean(liked_joint, dim=0, keepdim=True)
negative_anchor = torch.mean(disliked_joint, dim=0, keepdim=True)

# %%
print("style_anchor shape:", style_anchor.shape)
print("negative_anchor shape:", negative_anchor.shape)
# Out:
# style_anchor shape: torch.Size([1, 1, 512])
# negative_anchor shape: torch.Size([1, 1, 512])

# %%
print("Style Anchor Embedding:", style_anchor)
print("Negative Anchor Embedding:", negative_anchor)
# Out:
# Style Anchor Embedding: tensor([[[ 2.2366e-01, -1.5877e-01,  9.0211e-01,  8.2685e-01,  1.6340e-01,
#            1.5664e-01, -1.3843e-01, -7.2630e-03,  4.2761e-01,  5.7784e-02,
#            3.1500e-01, -1.8306e-01,  1.2633e-01, -1.4995e-01,  1.7120e-01,
#           -3.7351e-01,  6.9910e-02, -1.3889e-01,  2.8279e-01,  2.4198e-01,
#           -5.1334e-01, -7.8462e-02,  1.7118e-01, -9.8692e-01,  1.8611e-01,
#            2.3277e-01,  1.1330e-01,  9.1591e-02,  5.0786e-02, -6.8069e-02,
#           -1.6148e-01,  5.9783e-01, -2.3785e-01,  6.1609e-03, -2.9434e-01,
#            2.4997e-01,  4.2124e-02, -3.3424e-02,  3.5561e-01, -2.2458e-01,
#           -3.6564e-01, -9.3298e-02,  3.7153e-02, -9.3394e-02,  4.3627e-01,
#            4.1131e-02, -5.1049e-02,  1.6026e-01, -3.2340e-01, -2.1054e-01,
#           -5.1668e-01,  1.1531e-02,  1.3245e-01,  3.9304e-01, -1.1020e-01,
#           -2.2519e-01, -3.0141e-02,  9.0973e-02, -1.3104e-01, -1.0718e-01,
#           -1.2697e-01, -4.3541e-01,  3.5983e-01, -2.4906e-01, -3.3708e-01,
#            1.2097e-01, -7.5792e-02,  8.6243e-02, -1.7294e-01, -1.0684e-01,
#            2.5467e-01,  2.1709e-01, -1.5013e-01, -1.4403e-01, -1.1667e-01,
#            2.7623e-03, -1.7846e-02,  3.9496e-01, -2.6220e-01, -5.2303e-01,
#            1.4198e-01,  5.9967e-03, -1.1080e-01, -3.5152e-01, -1.6249e-01,
#            1.6093e-01,  1.5955e-01,  2.2639e-01, -7.2756e-02,  3.6675e-01,
#           -5.5389e-02, -1.3676e-01,  2.2885e-01,  5.3688e-02,  9.5321e-02,
#            1.5808e-02, -1.3272e-01,  2.8237e-02,  2.3924e-01, -9.7329e-02,
#           -3.2947e-01, -1.2416e-01,  3.3545e-02,  3.5372e-02,  1.8305e-01,
#           -5.3552e-01,  2.6122e-01, -2.1684e-01, -2.1983e-02, -1.8699e-02,
#           -1.4922e-01,  1.6501e-01,  5.7849e-01,  2.1929e-01, -5.7758e-02,
#           -2.2976e-01, -9.8938e-02,  1.5876e-01,  3.0472e-01,  5.6824e-02,
#            5.1023e-03, -9.1272e-02, -1.2128e-01, -2.0810e-01, -2.3204e-01,
#            2.0389e-01, -8.5661e-02,  3.7251e-02,  6.6397e-01,  2.3676e-02,
#           -1.5714e-02, -2.4450e-02, -1.6867e-01, -2.4694e-01,  1.4464e-02,
#           -7.5161e-02,  2.4286e-01, -1.8692e-01,  6.8624e-02,  3.8047e-01,
#            1.8208e-01, -1.3313e-01,  5.8158e-01,  3.6766e-01, -1.4548e-01,
#            4.3448e-01,  1.5707e-01, -1.3664e-01,  8.5668e-02, -2.4198e-01,
#           -1.1707e-01,  2.9395e-02,  2.1736e-01,  3.1661e-02,  4.0588e-01,
#            6.0654e-02, -8.5014e-02, -3.1979e-01,  1.3828e-01, -4.0799e-02,
#            8.4464e-01, -3.9000e-02, -1.0455e-01, -3.7351e-01,  1.7829e-01,
#           -5.3638e-02,  7.0085e-02, -8.8136e-03, -2.4598e-01,  8.4896e-02,
#            1.6090e-02,  1.6153e-01,  2.5183e-01, -1.8103e-01,  1.3343e-01,
#            2.1994e-01, -1.6975e-01,  3.1783e-02,  2.5326e-01,  2.4134e-02,
#           -4.0291e-01, -7.6702e-01, -8.2876e-02,  3.9117e-01, -7.2877e-02,
#            3.3950e-01,  3.0126e-01,  6.0000e-02,  5.3455e-01, -7.1784e-02,
#            7.4066e-02,  2.3994e-01,  2.5102e-02,  1.0960e-01,  2.7100e-01,
#            6.4498e-02, -9.3159e-02,  1.6967e-01,  2.9613e-01,  2.4096e-01,
#           -1.3799e-01, -1.7447e-01, -9.6883e-03, -1.4345e-01, -2.4489e-01,
#           -1.8788e-01,  8.4792e-02,  8.2545e-02,  2.2409e-01, -2.8182e-02,
#            3.2115e-01, -9.1375e-02,  3.2714e-02,  5.0621e-02,  2.9584e-03,
#            5.3706e-03,  2.3310e-01, -1.0378e-01, -2.9516e-01,  2.0623e-01,
#           -2.1320e-01, -3.3118e-01, -5.6046e-02, -1.4435e-01, -2.1790e-01,
#           -1.0683e-01,  7.8308e-02,  2.8687e-01, -1.3473e-01, -1.2085e-01,
#           -3.4213e+00, -2.2052e-01, -3.7310e-02, -8.5105e-01, -2.9490e-02,
#           -2.8322e-01, -4.2191e-01, -1.1828e-01, -8.5662e-01, -9.8841e-02,
#           -3.7679e-01,  1.4477e-01,  2.3109e-01,  1.7144e-01, -3.6987e-02,
#           -1.6023e-02,  8.4938e-02,  1.8720e-01,  3.2315e-01,  6.0349e-01,
#            1.9057e-01,  5.4426e-02, -2.7400e-01, -1.1330e-01,  1.0341e-01,
#           -2.6429e-02, -2.0314e-01,  9.3810e-02, -4.2552e-01, -2.1380e-01,
#            1.8876e-02, -1.6425e-01, -3.7827e-01,  6.2522e-02, -2.7364e-01,
#           -6.5909e-02, -4.9772e-02, -1.1143e-01, -3.9234e-02,  1.1292e-01,
#            2.3557e-01,  3.7762e-02, -3.2756e-02, -1.6795e-02, -1.1187e-01,
#            1.0568e-01,  1.2658e-01,  2.8675e-03,  7.3321e-02,  1.3342e-01,
#            4.7053e-02, -4.8978e-01,  2.9399e-01,  1.3094e+00, -2.8421e-01,
#           -1.5738e-02,  3.9106e-01, -5.7035e-01,  1.8072e-01, -1.6969e-01,
#            3.3711e-01,  1.1598e-01, -1.7035e-01,  2.1455e-01,  2.4616e-01,
#            1.9387e-01,  6.8965e-02, -1.4525e+00, -2.9681e-02,  7.1281e-01,
#            4.4977e-02,  2.9683e-01,  1.2626e-01, -1.9008e-03, -3.6251e-02,
#            3.2470e-01,  2.3047e-01, -2.5669e-01, -1.1115e-02, -5.1108e-02,
#            3.8343e-02, -8.2902e-02, -2.5620e-01,  1.0552e-01, -1.6265e-02,
#           -6.0991e-01,  6.7887e-02, -6.3003e-01,  7.9516e-02,  1.7781e-01,
#           -2.4556e-01, -8.3864e-02,  1.6144e-01,  1.0405e-01, -1.3108e-01,
#            1.1613e-01,  3.9404e-01, -4.6167e-02,  1.9938e-02,  1.2624e-01,
#           -6.4812e-02, -2.0631e-01, -6.0816e-02, -2.4715e-02,  1.5222e-01,
#           -1.5562e-02,  3.0017e-01, -7.9500e-03,  2.3486e-01,  2.7809e-01,
#           -2.5485e-01, -2.5250e-03, -2.5220e-01,  1.5507e-01,  1.2185e-01,
#            2.5755e-01,  9.4719e-02, -4.4626e-02, -1.3832e-01, -3.9627e-01,
#           -2.5184e-01,  1.8940e-01,  3.0753e-01,  6.0033e-02, -4.1394e-01,
#            3.9991e-02,  1.4989e-01,  1.4144e-01, -1.2510e-01, -6.7238e-02,
#           -3.1623e-02, -6.0994e-02,  1.6578e-01, -9.0118e-02,  1.6654e-01,
#           -4.1653e-01,  9.0434e-02,  7.0190e-02, -5.0471e-02,  2.4881e-01,
#            2.6693e-01,  3.9819e-02, -4.8623e-01, -4.9942e-01, -7.6755e-02,
#            1.0762e-01, -1.0235e-01, -5.0778e-01, -7.9109e-02, -8.3786e-02,
#            1.2803e-01, -4.6752e-02, -9.6062e-02, -1.7083e-02,  2.6900e-01,
#           -8.0866e-02,  7.2072e-02, -2.7388e-01, -1.7240e-02,  5.9765e-02,
#            1.7183e-01, -2.1503e-01,  3.3267e-01, -2.0595e-01,  6.9891e-01,
#           -1.1573e-01, -1.0350e-01,  1.7107e-01,  1.9222e-01,  2.4950e-01,
#            5.6858e-02, -3.3025e-02, -5.6549e-02, -2.1876e-01,  1.4606e-01,
#           -2.0735e-02,  1.7186e-02, -4.5102e-02, -1.4882e-01,  1.6566e-01,
#           -3.4589e-01, -1.4923e-01,  5.0774e-02,  2.0653e-01,  2.2769e-01,
#           -4.3471e-02, -1.7293e-01, -6.4742e-02, -5.6656e-02, -8.5008e-02,
#            9.1350e-02, -4.3402e+00, -9.9256e-02,  2.2652e-02,  1.7402e-01,
#           -1.3072e-01, -8.1604e-02, -4.8478e-02, -1.9772e-01, -1.6854e-01,
#           -1.3203e-01, -4.2766e-01,  2.8377e-02, -1.6740e-01, -2.1400e-01,
#           -3.0578e-01, -1.6863e-01,  5.9714e-03,  1.9220e-01, -3.2038e-01,
#           -6.3171e-02, -7.8498e-03, -1.4544e-01, -1.3376e-01, -1.4846e-01,
#            6.5042e-01, -7.4768e-02,  1.1746e-01,  1.0809e-01,  1.6182e-01,
#           -3.6920e-01, -2.4444e-01, -1.2977e-01, -3.4364e-01, -8.3409e-02,
#           -1.7544e-01, -6.5548e-01,  3.7231e-01,  2.3628e-01,  3.9812e-01,
#            5.9607e-01, -3.1679e-01,  1.5757e-02,  1.2327e-01,  1.4061e-01,
#           -4.6636e-02, -2.2893e-01, -4.2061e-02, -1.3358e-01,  9.7250e-02,
#           -3.2445e-01,  9.4100e-02, -2.1125e-02,  3.0304e-01, -3.2833e-01,
#           -1.2318e-01, -2.5256e-01,  3.1607e-02, -8.9749e-02, -1.6767e-01,
#            2.4618e-01,  2.3333e-01,  9.4657e-02,  7.2229e-02, -1.9088e-01,
#           -1.8441e-01, -2.8457e-01, -4.2895e-01, -2.9857e-01, -3.7822e-03,
#            2.2067e-01, -1.4625e-01, -1.0187e-01, -3.6611e-02, -9.3585e-02,
#           -5.2982e-02, -1.1532e-01,  5.7801e-02,  5.4089e-01, -3.8807e-01,
#            1.2385e-01,  1.0532e-01,  1.1778e-01, -1.4910e-01, -1.8711e-01,
#           -1.9255e-01,  9.9455e-02, -1.4429e-01,  1.3761e-01, -1.1545e-01,
#           -1.9674e-01,  1.8822e-01]]])
# Negative Anchor Embedding: tensor([[[ 3.8522e-01, -1.6047e-01,  1.0301e+00,  8.1639e-01,  2.4755e-01,
#            2.7197e-01, -1.8520e-01,  1.3146e-01,  3.4050e-01,  1.0667e-02,
#            2.6615e-01, -1.2721e-01,  1.7005e-01, -1.4446e-01,  1.8135e-01,
#           -1.3657e-01,  2.0645e-02, -2.1091e-01,  1.9532e-01,  2.1519e-01,
#           -5.4530e-01, -1.6745e-01,  2.7741e-02, -8.5622e-01,  2.9917e-01,
#            1.9862e-01,  1.6087e-01,  1.3361e-02,  1.3593e-01,  5.2177e-02,
#           -1.4632e-01,  4.4320e-01, -2.4180e-01,  8.5523e-02, -2.2745e-01,
#            2.7500e-01,  9.8827e-02,  4.3561e-02,  3.6804e-01, -1.0806e-01,
#           -3.7338e-01, -5.3237e-02, -1.1593e-01, -1.5404e-01,  4.5412e-01,
#            2.5711e-02, -3.2008e-02,  2.1846e-01, -3.3076e-01, -1.2671e-01,
#           -4.0319e-01, -4.3693e-02,  8.6275e-02,  3.6380e-01, -9.0259e-02,
#           -7.2270e-02,  7.8490e-03,  1.4734e-01, -8.2968e-02, -1.2584e-01,
#           -1.0637e-01, -4.2287e-01,  4.3230e-01, -1.8718e-01, -2.8733e-01,
#            1.6117e-01, -3.8154e-02,  5.0364e-02, -9.4754e-02, -1.1590e-01,
#            3.5927e-01,  1.6703e-01, -2.8844e-01, -2.4473e-01, -1.6626e-01,
#            6.8929e-02, -6.6768e-02,  3.9818e-01, -2.8948e-01, -5.3765e-01,
#            6.7038e-02, -1.9023e-02, -1.3420e-01, -4.7238e-01,  7.6863e-05,
#            8.0097e-02,  1.3826e-01,  1.7990e-01, -1.9099e-02,  3.0327e-01,
#           -1.6482e-01, -1.0001e-01,  2.5465e-01, -2.0006e-02,  1.4281e-01,
#           -4.6919e-02, -1.0743e-01, -6.0504e-02,  2.4254e-01,  5.3757e-03,
#           -2.4899e-01, -9.7813e-02,  1.0063e-01, -3.8823e-02,  1.4265e-01,
#           -5.2319e-01,  2.7869e-01, -2.2715e-01, -3.3879e-03,  4.1699e-02,
#           -3.3795e-01,  1.6805e-01,  6.8301e-01,  2.6086e-01, -2.8213e-02,
#           -2.3365e-01, -1.3509e-02,  1.6570e-01,  2.9432e-01,  1.4390e-01,
#           -1.8702e-02, -1.5029e-01, -2.0255e-01, -2.1623e-01, -2.2637e-01,
#            2.8210e-01, -6.3151e-02,  1.0508e-01,  6.1172e-01,  5.9516e-02,
#            1.6634e-01, -2.2517e-02, -1.4224e-01, -2.7314e-01,  6.2252e-02,
#           -6.6964e-02,  2.7838e-01, -7.3219e-02,  6.1618e-02,  3.2380e-01,
#            2.1145e-01, -1.5156e-02,  4.8591e-01,  2.4048e-01, -1.5175e-01,
#            3.5820e-01,  1.8125e-01, -6.7877e-02,  2.5323e-02, -3.0193e-01,
#           -1.2456e-01,  7.9247e-02,  2.9457e-01,  1.0123e-01,  4.1780e-01,
#            5.5496e-02, -5.1220e-02, -2.8472e-01,  1.5676e-01, -2.1536e-03,
#            7.7023e-01,  2.7953e-02, -1.8412e-01, -3.3165e-01,  1.9030e-01,
#           -3.9092e-02,  1.1160e-02, -4.9743e-02, -2.6278e-01,  9.3719e-02,
#           -5.2091e-03,  1.8366e-01,  3.1897e-01, -3.3801e-01,  1.7538e-01,
#            8.3531e-02, -1.5856e-01, -5.6144e-03,  1.6894e-01,  1.3089e-02,
#           -3.6871e-01, -8.9025e-01, -1.3662e-01,  2.5191e-01, -8.1549e-02,
#            3.6980e-01,  2.4225e-01,  9.7632e-02,  5.2601e-01, -1.4422e-01,
#            5.5904e-02,  1.7939e-01,  1.1782e-01,  7.3146e-02,  2.0917e-01,
#            9.6447e-02,  4.4403e-03,  1.4941e-01,  2.1402e-01,  3.5993e-01,
#           -1.2572e-01, -1.4423e-01,  4.8965e-02, -3.3782e-01, -2.3045e-01,
#           -1.3396e-01,  1.0371e-01, -9.7707e-03,  2.3674e-01, -1.6200e-02,
#            3.9353e-01, -1.3783e-01,  2.1240e-02,  1.2936e-01,  9.7667e-02,
#            1.6840e-02,  2.9548e-01, -2.4924e-01, -1.8718e-01,  2.3078e-01,
#           -2.6111e-01, -2.6471e-01, -5.9258e-02, -2.1742e-01, -3.2408e-01,
#           -8.6931e-02, -1.3045e-01,  2.9921e-01, -1.1782e-01, -2.2377e-01,
#           -3.0741e+00, -2.3586e-01,  1.6463e-02, -4.5537e-01, -3.4793e-02,
#           -2.6393e-01, -3.3633e-01, -1.4498e-01, -7.8013e-01, -5.0774e-02,
#           -2.9323e-01,  3.4357e-01,  2.4670e-01,  2.0005e-01, -2.2714e-01,
#           -8.0374e-02,  1.9568e-01,  9.3224e-02,  3.3554e-01,  4.9929e-01,
#            1.7641e-01, -5.6925e-02, -3.4368e-01, -8.9472e-02,  1.1531e-01,
#           -1.2842e-01, -1.3951e-01,  4.8663e-02, -6.1712e-01, -1.8333e-01,
#            1.0445e-01, -2.3069e-01, -3.5787e-01,  8.6159e-02, -3.5097e-01,
#           -7.9551e-02, -7.8223e-02, -1.2884e-01, -1.2451e-02,  2.3800e-01,
#            1.2408e-01,  9.0841e-02, -2.3757e-02, -4.5176e-02, -1.4526e-01,
#            9.4550e-02,  3.9577e-02,  2.8944e-02,  1.4845e-01,  1.7123e-02,
#            7.1044e-02, -3.0360e-01,  3.2439e-01,  1.2438e+00, -3.5166e-01,
#           -2.0083e-03,  2.7660e-01, -4.1681e-01,  2.3633e-01, -1.2900e-01,
#            2.3491e-01,  5.1560e-02, -8.3182e-02,  3.4403e-01,  3.0807e-01,
#            2.3974e-01,  8.2310e-02, -1.5002e+00, -2.8727e-02,  2.9650e-01,
#            5.7652e-02,  2.8922e-01,  1.6170e-01,  3.2532e-03, -7.1515e-02,
#            3.2265e-01,  2.5693e-01, -1.8322e-01,  3.0066e-02, -7.1624e-02,
#            3.8969e-02, -1.2900e-02, -3.1760e-01,  1.5644e-01, -3.5493e-03,
#           -6.3862e-01,  1.5128e-01, -6.0469e-01,  9.4645e-02,  1.9605e-01,
#           -3.0282e-01, -1.0732e-01,  1.5157e-01,  1.3750e-01, -2.2051e-01,
#            2.0663e-01,  3.7256e-01, -1.8617e-01,  1.9089e-01,  6.7498e-02,
#            3.5805e-02, -2.1218e-01, -5.9392e-02, -1.0128e-01,  1.2395e-01,
#            8.2276e-03,  1.7459e-01, -1.4046e-02,  2.3659e-01,  1.9243e-01,
#           -2.3941e-01, -9.0468e-02, -1.7448e-01,  1.9544e-01,  1.7289e-01,
#            1.8879e-01,  1.3305e-01, -9.4970e-02, -7.1433e-02, -3.3510e-01,
#           -3.1610e-01, -9.5791e-02,  2.9558e-01,  1.8391e-01, -3.2383e-01,
#            1.0673e-01,  2.0048e-01,  1.0733e-01, -1.1993e-01, -8.1780e-02,
#           -5.2684e-02, -1.4209e-01,  1.2208e-01, -1.3342e-01,  1.8289e-01,
#           -2.4090e-01,  1.1014e-01,  3.3619e-02,  1.3270e-01,  2.0762e-01,
#            2.1801e-01,  6.6462e-02, -5.9508e-01, -4.7052e-01, -1.1001e-01,
#            1.9509e-01, -8.8050e-02, -3.7793e-01, -4.7697e-02, -6.0926e-02,
#            4.1994e-02, -6.6280e-02, -8.2665e-02, -7.1208e-02,  1.4461e-01,
#           -3.2553e-02,  5.9282e-02, -3.0799e-01,  3.4092e-02,  1.2370e-02,
#            1.1048e-01, -1.9351e-01,  3.2091e-01, -3.3903e-01,  3.7608e-01,
#           -1.1093e-01, -5.9255e-02,  2.6849e-01,  1.6738e-01,  2.7534e-01,
#            3.4113e-02, -2.2791e-01, -1.2998e-01, -2.1698e-01,  1.7089e-01,
#           -5.1503e-02,  1.0341e-02, -3.9759e-01, -1.7330e-01,  1.5879e-01,
#           -3.2522e-01, -1.2812e-01,  5.5235e-02,  1.3187e-01,  1.6081e-01,
#           -9.9243e-02, -2.2377e-01, -2.9327e-02, -2.0704e-02, -1.3467e-01,
#            7.0001e-02, -4.2558e+00,  9.3351e-02,  1.5433e-01,  2.1632e-01,
#           -2.3818e-01, -2.1773e-01,  3.7369e-01, -1.8173e-01, -9.4349e-02,
#           -5.9180e-02, -4.9977e-01,  8.9178e-02, -1.6208e-01, -3.0637e-01,
#           -2.7132e-01, -1.3632e-01,  3.7013e-02,  2.0439e-01, -3.2981e-01,
#           -1.1268e-02, -1.3551e-01, -2.4638e-01, -2.0155e-01, -1.6339e-01,
#            5.6381e-01, -7.4600e-02,  2.1799e-01,  7.1292e-02, -4.1818e-02,
#           -4.2431e-01, -2.9526e-01, -1.0575e-01, -3.4243e-01, -1.1273e-01,
#           -1.9306e-01, -5.2522e-01,  2.9624e-01,  2.0836e-01,  3.5146e-01,
#            5.4631e-01, -3.1065e-01, -3.4345e-02,  1.6390e-01,  1.7664e-01,
#           -4.1128e-02, -2.2829e-01, -5.4532e-02, -1.5737e-01,  1.6275e-01,
#           -3.9721e-01,  1.0732e-03, -1.0306e-01,  3.0734e-01, -2.1466e-01,
#           -1.1220e-01, -2.4266e-01,  5.3697e-02, -1.4008e-01,  2.2060e-01,
#            5.0516e-02,  2.5590e-01,  4.0285e-02,  6.5401e-02, -2.1583e-01,
#           -2.3259e-01, -2.4173e-01, -3.9201e-01, -2.9801e-01, -7.6741e-02,
#            2.7201e-01, -8.4004e-02, -1.8238e-01, -7.3814e-03, -4.3921e-02,
#           -6.3360e-02, -8.6742e-02,  3.6531e-02,  5.4908e-01, -3.0582e-01,
#            2.0938e-01,  1.3677e-02,  4.9186e-02, -2.5225e-01, -8.6789e-02,
#           -2.3129e-01, -2.2124e-02, -1.3321e-01,  1.8965e-01, -1.3445e-01,
#           -1.9070e-01,  1.1345e-01]]])

# %%
correct_count = 0
faulty_count = 0

for image_path, embedding in embeddings.items():
    embedding = embedding.to(config.DEVICE)
    style_anchor = style_anchor.to(config.DEVICE)
    negative_anchor = negative_anchor.to(config.DEVICE)
    score = score_image(embedding, style_anchor, negative_anchor)
    scores[image_path] = score

    print(f"Image: {image_path}")
    print(f"Personalized score: {score:.4f}")

    # Condition checks
    if (score > score_threshold and 'good' in image_path) or \
       (score < score_threshold and 'bad' in image_path):
        print("classification correct\n")
        correct_count += 1
    else:
        print("classification faulty\n")
        faulty_count += 1

not_rated = 0

# Final summary
print(f"Total correct classifications: {correct_count} out of {correct_count + faulty_count - not_rated} ({correct_count / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
print(f"Total faulty classifications: {faulty_count - not_rated} out of {correct_count + faulty_count - not_rated} ({(faulty_count - not_rated) / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
# Out:
# Image: ../../data/outfits/outfits_to_test/10_good_o.jpg
# Personalized score: 0.5007
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/11_good_o.jpg
# Personalized score: 0.5159
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/12_good_o.jpg
# Personalized score: 0.5139
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/13_bad_o.jpg
# Personalized score: 0.4968
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/14_bad_o.jpg
# Personalized score: 0.4956
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/15_good_o.jpg
# Personalized score: 0.4966
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/16_good_o.jpg
# Personalized score: 0.4778
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/17_bad_o.jpg
# Personalized score: 0.4980
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/18_bad_o.jpg
# Personalized score: 0.5016
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/19_good_o.jpg
# Personalized score: 0.5404
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_o.jpg
# Personalized score: 0.5221
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_s.jpg
# Personalized score: 0.5070
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/20_good_o.jpg
# Personalized score: 0.5125
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/21_bad_o.jpg
# Personalized score: 0.5001
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/22_good_o.jpg
# Personalized score: 0.5079
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/23_bad_o.jpg
# Personalized score: 0.5143
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/24_bad_o.jpg
# Personalized score: 0.5000
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/25_good_o.jpg
# Personalized score: 0.4822
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/26_bad_o.jpg
# Personalized score: 0.5127
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/27_good_o.jpg
# Personalized score: 0.5145
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/28_bad_o.jpg
# Personalized score: 0.4844
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/29_bad_o.jpg
# Personalized score: 0.5051
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_o.jpg
# Personalized score: 0.4862
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/2_bad_s.jpg
# Personalized score: 0.4901
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/30_bad_o.jpg
# Personalized score: 0.5081
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/31_good_o.jpg
# Personalized score: 0.5198
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/32_good_o.jpg
# Personalized score: 0.4903
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/33_bad_o.jpg
# Personalized score: 0.4960
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/34_good_o.jpg
# Personalized score: 0.5130
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/35_good_o.jpg
# Personalized score: 0.5027
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_o.jpg
# Personalized score: 0.4812
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_s.jpg
# Personalized score: 0.4752
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/5_bad_o.jpg
# Personalized score: 0.4868
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/5_bad_s.jpg
# Personalized score: 0.4841
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_o.jpg
# Personalized score: 0.5096
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_s.jpg
# Personalized score: 0.5111
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_o.jpg
# Personalized score: 0.4831
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_s.jpg
# Personalized score: 0.4761
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/8_bad_o.jpg
# Personalized score: 0.4736
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/9_good_o.jpg
# Personalized score: 0.5082
# classification correct
#
# Total correct classifications: 30 out of 40 (75.00%)
# Total faulty classifications: 10 out of 40 (25.00%)

# %%
correct_count = 0
faulty_count = 0

for image_path, embedding in embeddings.items():
    embedding = embedding.to(config.DEVICE)
    style_anchor = style_anchor.to(config.DEVICE)
    negative_anchor = negative_anchor.to(config.DEVICE)
    score = score_image(embedding, style_anchor, negative_anchor, "A chic, elegant outfit")
    scores[image_path] = score

    print(f"Image: {image_path}")
    print(f"Personalized score: {score:.4f}")

    # Condition checks
    if (score > score_threshold and 'good' in image_path) or \
       (score < score_threshold and 'bad' in image_path):
        print("classification correct\n")
        correct_count += 1
    else:
        print("classification faulty\n")
        faulty_count += 1

not_rated = 0

# Final summary
print(f"Total correct classifications: {correct_count} out of {correct_count + faulty_count - not_rated} ({correct_count / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
print(f"Total faulty classifications: {faulty_count - not_rated} out of {correct_count + faulty_count - not_rated} ({(faulty_count - not_rated) / (correct_count + faulty_count - not_rated) * 100:.2f}%)")
# Out:
# Image: ../../data/outfits/outfits_to_test/10_good_o.jpg
# Personalized score: 0.5364
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/11_good_o.jpg
# Personalized score: 0.5344
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/12_good_o.jpg
# Personalized score: 0.5346
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/13_bad_o.jpg
# Personalized score: 0.5363
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/14_bad_o.jpg
# Personalized score: 0.5246
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/15_good_o.jpg
# Personalized score: 0.5425
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/16_good_o.jpg
# Personalized score: 0.5281
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/17_bad_o.jpg
# Personalized score: 0.5431
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/18_bad_o.jpg
# Personalized score: 0.5395
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/19_good_o.jpg
# Personalized score: 0.5684
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_o.jpg
# Personalized score: 0.5463
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/1_good_s.jpg
# Personalized score: 0.5248
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/20_good_o.jpg
# Personalized score: 0.5403
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/21_bad_o.jpg
# Personalized score: 0.5167
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/22_good_o.jpg
# Personalized score: 0.5413
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/23_bad_o.jpg
# Personalized score: 0.5402
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/24_bad_o.jpg
# Personalized score: 0.5355
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/25_good_o.jpg
# Personalized score: 0.5236
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/26_bad_o.jpg
# Personalized score: 0.5451
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/27_good_o.jpg
# Personalized score: 0.5467
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/28_bad_o.jpg
# Personalized score: 0.5395
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/29_bad_o.jpg
# Personalized score: 0.5327
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_o.jpg
# Personalized score: 0.5283
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/2_bad_s.jpg
# Personalized score: 0.5239
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/30_bad_o.jpg
# Personalized score: 0.5394
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/31_good_o.jpg
# Personalized score: 0.5574
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/32_good_o.jpg
# Personalized score: 0.5487
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/33_bad_o.jpg
# Personalized score: 0.5273
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/34_good_o.jpg
# Personalized score: 0.5353
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/35_good_o.jpg
# Personalized score: 0.5282
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/3_bad_o.jpg
# Personalized score: 0.5271
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/3_bad_s.jpg
# Personalized score: 0.5113
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/5_bad_o.jpg
# Personalized score: 0.5335
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/5_bad_s.jpg
# Personalized score: 0.5230
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/6_good_o.jpg
# Personalized score: 0.5404
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/6_good_s.jpg
# Personalized score: 0.5372
# classification correct
#
# Image: ../../data/outfits/outfits_to_test/7_bad_o.jpg
# Personalized score: 0.5274
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/7_bad_s.jpg
# Personalized score: 0.5080
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/8_bad_o.jpg
# Personalized score: 0.5158
# classification faulty
#
# Image: ../../data/outfits/outfits_to_test/9_good_o.jpg
# Personalized score: 0.5371
# classification correct
#
# Total correct classifications: 19 out of 40 (47.50%)
# Total faulty classifications: 21 out of 40 (52.50%)

# %%
import torch
import numpy as np
import umap
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from mpl_toolkits.mplot3d import Axes3D

# Squeeze out the singleton dimension to get (N, 512)
liked_emb = liked_image_embeddings.squeeze(1).cpu().numpy()    # (816, 512)
disliked_emb = disliked_image_embeddings.squeeze(1).cpu().numpy()  # (4651, 512)

# Combine embeddings and create labels
embeddings = np.concatenate([liked_emb, disliked_emb], axis=0)
labels = np.array([1] * liked_emb.shape[0] + [0] * disliked_emb.shape[0])  # 1=liked, 0=disliked

# Color map: 0=blue (disliked), 1=orange (liked)
color_map = np.array(['blue', 'orange'])

# 2D UMAP Visualization
umap_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(embeddings)
plt.figure(figsize=(8, 8))
plt.scatter(umap_2d[:, 0], umap_2d[:, 1], c=color_map[labels], alpha=0.7)
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Disliked (blue)', markerfacecolor='blue', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Liked (orange)', markerfacecolor='orange', markersize=10)
]
plt.legend(handles=legend_elements, title='Outfit Quality')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.tight_layout()
plt.savefig('fashion-clip-embeddings-2d-visualization.png')
plt.close()

# 3D UMAP Visualization
umap_3d = umap.UMAP(n_components=3, random_state=42).fit_transform(embeddings)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
for label, color, name in zip([0, 1], ['blue', 'orange'], ['Disliked', 'Liked']):
    idxs = np.where(labels == label)
    ax.scatter(umap_3d[idxs, 0], umap_3d[idxs, 1], umap_3d[idxs, 2], c=color, label=f'{name} ({color})', alpha=0.7)
ax.set_xlabel('UMAP Dimension 1')
ax.set_ylabel('UMAP Dimension 2')
ax.set_zlabel('UMAP Dimension 3')
ax.legend(title='Outfit Quality')
plt.tight_layout()
plt.savefig('fashion-clip-embeddings-3d-visualization.png')
plt.close()
# Out:
# /Users/tori/miniconda3/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/tori/miniconda3/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Assume style_anchor and negative_anchor are (1, 1, 512) tensors
# Remove extra dimensions to get (2, 512)
anchors = torch.stack([
    style_anchor.squeeze(0).squeeze(0),   # (512,)
    negative_anchor.squeeze(0).squeeze(0) # (512,)
], dim=0)  # shape: (2, 512)
print(anchors.shape)
# Out:
# torch.Size([2, 512])

# %%
anchors_np = anchors.cpu().numpy()
print(anchors_np.shape)  # should be (2, 512)
print(anchors_np)
# Out:
# (2, 512)
# [[ 0.2236568  -0.1587712   0.90210813 ... -0.11545078 -0.1967367
#    0.18821849]
#  [ 0.3852181  -0.16047184  1.0301242  ... -0.13445272 -0.1907
#    0.1134533 ]]

# %%
from sklearn.decomposition import PCA

# anchors_np: shape (2, 512)
pca = PCA(n_components=2)
anchors_2d = pca.fit_transform(anchors_np)
colors = ['orange', 'blue']  # orange = liked, blue = disliked
labels = ['Liked (Style Anchor)', 'Disliked (Negative Anchor)']

plt.figure(figsize=(8, 8))
for i in range(2):
    plt.scatter(anchors_2d[i, 0], anchors_2d[i, 1], color=colors[i], s=100, label=labels[i])
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=labels[i], markerfacecolor=colors[i], markersize=10)
    for i in range(2)
]
plt.legend(handles=legend_elements, title='Anchor Type')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.tight_layout()
plt.savefig('fashion-clip-anchors-embeddings-2d-visualization.png')
plt.close()
